# %% [markdown]
# # VacationPy
# ___

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# Load cities.csv to a DataFrame

cities_data = pd.read_csv("Cities.csv")
#cities_data.set_index("City_ID")

# Make sure to handle NaN values

cities_data = cities_data.dropna()
cities_data.set_index("City_ID")
cities_data
# Out:
#      City_ID         City Country  Latitude  Longitude  Max Temp  Humidity  \
# 0          0    Catamarca      AR    -28.47     -65.79     66.99        79
# 1          1    Hopelchen      MX     19.77     -89.85     86.00        74
# 2          2      Huilong      CN     31.81     121.66     64.99        94
# 3          3  Port alfred      ZA    -33.59      26.89     60.01        88
# 4          4  Pangnirtung      CA     66.15     -65.71     12.20        78
# ..       ...          ...     ...       ...        ...       ...       ...
# 497      497    Argalasti      GR     39.23      23.22     53.01        62
# 498      498     Cabedelo      BR     -6.98     -34.83     78.80        88
# 499      499  Pundaguitan      PH      6.37     126.17     83.44        76
# 500      500        Dinar      TR     38.06      30.17     48.20        93
# 501      501    Palembang      ID     -2.92     104.75     78.80        94
#
#      Cloudiness  Wind Speed
# 0             6        1.99
# 1            20       11.41
# 2           100        7.00
# 3             0        1.01
# 4            90       14.99
# ..          ...         ...
# 497          20        6.93
# 498          20        5.82
# 499          17        3.27
# 500          75        0.38
# 501          20        4.70
#
# [499 rows x 9 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure gmaps with API key

gmaps.configure(api_key = g_key)

# %%
# Convert 'Lat' and 'Lng' and Humidity to float and Store 

locations = cities_data[["Latitude", "Longitude"]].astype(float)

Humidities = cities_data["Humidity"].astype(float)

# %%
# Create a poverty Heatmap layer

fig = gmaps.figure(map_type="HYBRID")

heat_layer = gmaps.heatmap_layer(locations, 
                                 weights = Humidities, 
                                 dissipating = False, 
                                 opacity = 0.8,
                                 max_intensity=200,
                                 point_radius = 2)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
narrowed_city_df = cities_data.loc[
                                    (cities_data["Max Temp"] < 85) & 
                                    (cities_data["Max Temp"] > 65) & 
                                    (cities_data["Wind Speed"] < 10) & 
                                    (cities_data["Cloudiness"] < 10)
                                  ].dropna()
narrowed_city_df.set_index("City_ID")
# Out:
#                      City Country  Latitude  Longitude  Max Temp  Humidity  \
# City_ID
# 0               Catamarca      AR    -28.47     -65.79     66.99        79
# 10              Sarangani      PH      5.40     125.46     83.95        71
# 18                 Avarua      CK    -21.21    -159.78     80.60        83
# 83           Saint-pierre      RE    -21.34      55.48     75.20        73
# 93               Hurghada      EG     27.26      33.81     78.80        25
# 95                   Tura      IN     25.52      90.22     72.66        71
# 97                   Tezu      IN     27.92      96.17     72.95        62
# 167              Pasighat      IN     28.07      95.33     72.88        68
# 236                 Houma      US     29.60     -90.72     81.00        65
# 251      Saint pete beach      US     27.73     -82.74     82.00        54
# 278             Myitkyina      MM     25.38      97.40     71.73        88
# 280          Saint george      US     37.10    -113.58     84.00        13
# 285                 Nagda      IN     23.45      75.42     77.76        36
# 288               Tuy hoa      VN     13.08     109.30     78.94        79
# 318                 Luebo      CD     -5.35      21.42     72.10        75
# 330           Grand gaube      MU    -20.01      57.66     73.99        78
# 351              Sabzevar      IR     36.21      57.68     65.75        35
# 363          Sao domingos      BR    -13.40     -46.32     70.29        62
# 440               Sambava      MG    -14.27      50.17     72.95        76
# 448             Saquarema      BR    -22.92     -42.51     71.60        78
# 466            Dawlatabad      AF     36.41      64.91     67.39        48
# 473             Marrakesh      MA     31.63      -8.01     68.00        64
#
#          Cloudiness  Wind Speed
# City_ID
# 0                 6        1.99
# 10                0        2.75
# 18                7        5.82
# 83                3        5.82
# 93                0        9.17
# 95                0        4.85
# 97                6        2.62
# 167               5        1.86
# 236               1        9.17
# 251               1        6.93
# 278               1        2.68
# 280               1        4.70
# 285               3        8.34
# 288               0        3.29
# 318               2        2.13
# 330               6        1.99
# 351               0        3.04
# 363               6        5.17
# 440               1        6.17
# 448               7        3.36
# 466               0        3.00
# 473               9        5.82

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country and coordinates

hotel_df = narrowed_city_df[["City", "Country", "Max Temp", "Latitude", "Longitude"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#                  City Country  Max Temp  Latitude  Longitude Hotel Name
# 0           Catamarca      AR     66.99    -28.47     -65.79
# 10          Sarangani      PH     83.95      5.40     125.46
# 18             Avarua      CK     80.60    -21.21    -159.78
# 83       Saint-pierre      RE     75.20    -21.34      55.48
# 93           Hurghada      EG     78.80     27.26      33.81
# 95               Tura      IN     72.66     25.52      90.22
# 97               Tezu      IN     72.95     27.92      96.17
# 167          Pasighat      IN     72.88     28.07      95.33
# 236             Houma      US     81.00     29.60     -90.72
# 251  Saint pete beach      US     82.00     27.73     -82.74
# 278         Myitkyina      MM     71.73     25.38      97.40
# 280      Saint george      US     84.00     37.10    -113.58
# 285             Nagda      IN     77.76     23.45      75.42
# 288           Tuy hoa      VN     78.94     13.08     109.30
# 318             Luebo      CD     72.10     -5.35      21.42
# 330       Grand gaube      MU     73.99    -20.01      57.66
# 351          Sabzevar      IR     65.75     36.21      57.68
# 363      Sao domingos      BR     70.29    -13.40     -46.32
# 440           Sambava      MG     72.95    -14.27      50.17
# 448         Saquarema      BR     71.60    -22.92     -42.51
# 466        Dawlatabad      AF     67.39     36.41      64.91
# 473         Marrakesh      MA     68.00     31.63      -8.01

# %%
# Build the base URL for google apis
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# Set parameters to search for a hotel

params = { "radius": 5000,
           "types": "lodging",
           "key": g_key
         }

# use iterrows to iterate through pandas dataframe

for index, row in hotel_df.iterrows():
    
    # get latitude , longitude from df
    
    lat = row["Latitude"]
    lng = row["Longitude"]
    
    params["location"] = f"{lat},{lng}"
    
    # make request and print url
    response = requests.get(base_url, params=params)
    
    # Convert to json
    response_json = response.json()
    
    # Grab the first hotel from the results and store the name
    
    try:
        hotel_df.loc[index, "Hotel Name"] = response_json["results"][0]["name"]
        
    except (KeyError, IndexError):
        
        print("Missing field/result... skipping.")

hotel_df
# Out:
# Missing field/result... skipping.
#                  City Country  Max Temp  Latitude  Longitude  \
# 0           Catamarca      AR     66.99    -28.47     -65.79
# 10          Sarangani      PH     83.95      5.40     125.46
# 18             Avarua      CK     80.60    -21.21    -159.78
# 83       Saint-pierre      RE     75.20    -21.34      55.48
# 93           Hurghada      EG     78.80     27.26      33.81
# 95               Tura      IN     72.66     25.52      90.22
# 97               Tezu      IN     72.95     27.92      96.17
# 167          Pasighat      IN     72.88     28.07      95.33
# 236             Houma      US     81.00     29.60     -90.72
# 251  Saint pete beach      US     82.00     27.73     -82.74
# 278         Myitkyina      MM     71.73     25.38      97.40
# 280      Saint george      US     84.00     37.10    -113.58
# 285             Nagda      IN     77.76     23.45      75.42
# 288           Tuy hoa      VN     78.94     13.08     109.30
# 318             Luebo      CD     72.10     -5.35      21.42
# 330       Grand gaube      MU     73.99    -20.01      57.66
# 351          Sabzevar      IR     65.75     36.21      57.68
# 363      Sao domingos      BR     70.29    -13.40     -46.32
# 440           Sambava      MG     72.95    -14.27      50.17
# 448         Saquarema      BR     71.60    -22.92     -42.51
# 466        Dawlatabad      AF     67.39     36.41      64.91
# 473         Marrakesh      MA     68.00     31.63      -8.01
#
#                                             Hotel Name
# 0                         Amerian Catamarca Park Hotel
# 10                                     Ballistic Islet
# 18                                        Paradise Inn
# 83                                       Lindsey Hôtel
# 93                          Sea Star Beau Rivage Hotel
# 95                            Hotel RIKMAN Continental
# 97                                       Circuit House
# 167                                  Siang Guest House
# 236                        Courtyard by Marriott Houma
# 251                     TradeWinds Island Grand Resort
# 278                                    Shwe Phyu Hotel
# 280                        Best Western Plus Abbey Inn
# 285                              Hotel Rudraksh Palace
# 288                            CenDeluxe Hotel Tuy Hoa
# 318
# 330               Veranda Paul et Virginie Hotel & Spa
# 351                           پارکینگ وسایل سنگین جنوب
# 363  Hotel e Restaurante Uirapuru (Márcio uirapuru ...
# 440                                            Melrose
# 448                            Hotel Fazenda Sol e Lua
# 466                                   WASIM ASGAR KHAN
# 473                        Les Jardins de La Koutoubia

# %%
# Create list of hotels to use for hover_text

hotels = []

for hotel in hotel_df["Hotel Name"]:
    hotels.append(hotel)

print(hotels)
# Out:
# ['Amerian Catamarca Park Hotel', 'Ballistic Islet', 'Paradise Inn', 'Lindsey Hôtel', 'Sea Star Beau Rivage Hotel', 'Hotel RIKMAN Continental', 'Circuit House', 'Siang Guest House', 'Courtyard by Marriott Houma', 'TradeWinds Island Grand Resort', 'Shwe Phyu Hotel', 'Best Western Plus Abbey Inn', 'Hotel Rudraksh Palace', 'CenDeluxe Hotel Tuy Hoa', '', 'Veranda Paul et Virginie Hotel & Spa', 'پارکینگ وسایل سنگین جنوب', 'Hotel e Restaurante Uirapuru (Márcio uirapuru )Em São Domingos -Go', 'Melrose', 'Hotel Fazenda Sol e Lua', 'WASIM ASGAR KHAN', 'Les Jardins de La Koutoubia']

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Latitude", "Longitude"]]

# %%
# Add marker layer ontop of heat map

marker_layer = gmaps.marker_layer(locations, info_box_content = hotel_info, hover_text = hotels)
fig.add_layer(marker_layer)

# Display Map

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
