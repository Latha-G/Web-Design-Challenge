# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ## Generate Cities List
# ---

# %%
# Range of latitudes and longitudes

lat_range = (-90, 90)
lng_range = (-180, 180)

# Lists for holding latitudes-longitudes and cities

lat_lngs = []
cities = []

# Create a set of random lat and lng combinations

lats = np.random.uniform(low = -90.000, high = 90.000, size = 1200)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 1200)

lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination

for lat_lng in lat_lngs:
    
    City = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name.capitalize()
    
    # If the city is unique, then add it to cities list
    
    if City not in cities:
        cities.append(City)
        
# Print the city count and cities list

print(f'\n{len(cities)} cities are selected.\n')
print(cities)
# Out:
# 518 cities are selected.
#
# ['Castro', 'Bluff', 'Talnakh', 'New norfolk', 'Nikolskoye', 'Lypnyazhka', 'Punta arenas', 'Mahebourg', 'Thompson', 'Moyale', 'Port alfred', 'Vila', 'Tuktoyaktuk', 'Georgetown', 'Tasiilaq', 'Hithadhoo', 'Ushuaia', 'Ancud', 'Atuona', 'Turayf', 'Lorengau', 'Ponta do sol', 'Dikson', 'Juneau', 'Sitka', 'Teahupoo', 'Airai', 'Vaini', 'Tasbuget', 'Egvekinot', 'Avarua', 'Bambous virieux', 'Lebu', 'Pontianak', 'Broome', 'Hobart', 'Chuy', 'Kapaa', 'North bend', 'Noumea', 'Klaksvik', 'Nyrob', 'Severo-kurilsk', 'Cockburn town', 'Casablanca', 'Saint-francois', 'Bathsheba', 'Ugoofaaru', 'Mataura', 'Cape town', 'Aykhal', 'Saint-philippe', 'Rikitea', 'Yellowknife', 'Jamestown', 'Jinchang', 'Capao bonito', 'Tual', 'Taolanaro', 'Beloha', 'Puerto ayora', 'Barentsburg', 'Cherskiy', 'Barrow', 'Matagami', 'Qaanaaq', 'Katsuura', 'Chokurdakh', 'Alofi', 'Santa maria', 'Dhidhdhoo', 'Busselton', 'Mount isa', 'Lac du bonnet', 'Constitucion', 'Bonoua', 'Taoudenni', 'Lucapa', 'Bredasdorp', 'Vila velha', 'Cabo san lucas', 'Itaueira', 'Taltal', 'Lowicz', 'Dunedin', 'Tsihombe', 'Belushya guba', 'Los llanos de aridane', 'Hilo', 'Bengkulu', 'Aksu', 'Bose', 'Sorland', 'Vardo', 'Fort saint john', 'Tianpeng', 'Geraldton', 'Pasni', 'Antofagasta', 'Samusu', 'Ostrovnoy', 'Manokwari', 'Mar del plata', 'Nkayi', 'Kutum', 'Kokopo', 'Lahti', 'Nizhneyansk', 'Vila franca do campo', 'Touros', 'Hofn', 'Felidhoo', 'Faanui', 'Albany', 'Asau', 'Codrington', 'Amderma', 'Torbay', 'Sovetskiy', 'Havoysund', 'Rawson', 'Talawdi', 'Umzimvubu', 'Palabuhanratu', 'Iqaluit', 'Opaka', 'Narsaq', 'Nuristan', 'Sambava', 'Impfondo', 'Vao', 'Longyearbyen', 'Butaritari', 'Illoqqortoormiut', 'Atar', 'Vanavara', 'College', 'Kuandian', 'Jiayuguan', 'Saleaula', 'Clyde river', 'Nanortalik', 'San martin', 'Ban nahin', 'Cizre', 'Roald', 'Margate', 'Yar-sale', 'Itoman', 'Lompoc', 'Marv dasht', 'Barcelona', 'Mudgee', 'Avera', 'Bethel', 'Nador', 'Ribeira grande', 'Hermanus', 'Saskylakh', 'Onega', 'Mercedes', 'Kamaishi', 'Port-cartier', 'Ginda', 'Edson', 'Gurskoye', 'Sterlibashevo', 'Leningradskiy', 'Tabuny', 'Arraial do cabo', 'Kavaratti', 'Joshimath', 'Poya', 'Latung', 'Tidore', 'Derzhavinsk', 'Grand centre', 'Si sa ket', 'Straumen', 'Port elizabeth', 'Boa vista', 'Souillac', 'Lolua', 'Juba', 'Flinders', 'Jalu', 'Port lincoln', 'Hirna', 'Dhekiajuli', 'Matongo', 'Namibe', 'Tuatapere', 'Luanda', 'Gisborne', 'Hornepayne', 'Namatanai', 'Kerteh', 'Taicheng', 'Portalegre', 'Tawkar', 'Pechenga', 'Anadyr', 'Guerrero negro', 'Dong hoi', 'East london', 'Hay river', 'Saint george', 'Uruzgan', 'Kiknur', 'Mayo', 'Khatanga', 'Nome', 'Adrar', 'Paradwip', 'Grand river south east', 'Kargasok', 'Yahotyn', 'Salyan', 'Okhotsk', 'Tessalit', 'Mwinilunga', 'Upernavik', 'Barawe', 'Longido', 'Neuquen', 'Pochutla', 'Yuanli', 'Lazaro cardenas', 'Pangkalanbuun', 'Provideniya', 'Naze', 'Arrifes', 'Sao joao da barra', 'Bestobe', 'Zambezi', 'Tumannyy', 'Stoyba', 'Pisco', 'Vestmannaeyjar', 'Manicore', 'Neyshabur', 'Komsomolets', 'Suchitoto', 'Caronport', 'Grindavik', 'San jose', 'Ishigaki', 'Muravlenko', 'Pevek', 'Attawapiskat', 'Jacqueville', 'Takayama', 'Lavrentiya', 'Carnarvon', 'Calabozo', 'Xuddur', 'Hasaki', 'Arkhipo-osipovka', 'San patricio', 'Pilao arcado', 'Halmstad', 'Itaituba', 'Singaraja', 'Cayenne', 'Kyabram', 'North battleford', 'Bilma', 'Vangaindrano', 'Mucurapo', 'Ca mau', 'Kastamonu', 'Oistins', 'Arman', 'Tazovskiy', 'Valparaiso', 'Iowa city', 'Kjollefjord', 'Rio claro', 'Bredy', 'Marsa matruh', 'San vicente', 'Ilulissat', 'Sentyabrskiy', 'Husavik', 'Naliya', 'Hudson bay', 'Dumbraveni', 'Omboue', 'Piacabucu', 'Orange', 'Puerto baquerizo moreno', 'Ayan', 'Chalus', 'Esperance', 'Bar harbor', 'Kaeo', 'Meinung', 'Decatur', 'Walvis bay', 'Laguna', 'La brea', 'Meyungs', 'Pangody', 'Yulara', 'Ijaki', 'Kaitangata', 'Praia da vitoria', 'Awbari', 'Payson', 'Luderitz', 'Padang', 'Necochea', 'Chipoka', 'Comodoro rivadavia', 'Ahipara', 'Brae', 'Narrabri', 'Boundiali', 'Gat', 'Safaqis', 'Victoria', 'Muhos', 'Aklavik', 'Tabas', 'Belmont ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#api.openweathermap.org/data/2.5/weather?q={city name}&appid={your api key}

base_url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&q="


Cities_Data = []


for i, City in enumerate(cities):
    
    query_url = base_url + str(City) + "&appid=" + weather_api_key
    
    try:
        
        data = requests.get(query_url).json()
        
        Country = data['sys']['country']
        
        print(f'{i}. Processing data for {City}, {Country}')
        
        latitude = data["coord"]["lat"]
        
        longitude = data["coord"]["lon"]
        
        temperature = data["main"]["temp_max"]
        
        humidity = data["main"]["humidity"]
        
        Cloudiness = data["clouds"]["all"]
        
        Wind_speed = data["wind"]["speed"]
        
        Cities_Data.append({
                          "City" : City,
                          "Country" : Country,
                          "Latitude" : latitude,
                          "Longitude" : longitude,
                          "Max Temp" : temperature,
                          "Humidity" : humidity,
                          "Cloudiness" : Cloudiness,
                          "Wind Speed" : Wind_speed
                         })
        
    except:
        print(f'\n{i}. City - {City} is not found! Skipping.....\n')
        pass
    
              
# Indicate that Data Loading is complete

print("\n^^^^^^^^^^^^^^^^^^^^^^^^")
print("Data Retrieval Complete      ")
print("\n^^^^^^^^^^^^^^^^^^^^^^^^\n")
# Out:
# 0. Processing data for Castro, BR
# 1. Processing data for Bluff, NZ
# 2. Processing data for Talnakh, RU
# 3. Processing data for New norfolk, AU
# 4. Processing data for Nikolskoye, RU
# 5. Processing data for Lypnyazhka, UA
# 6. Processing data for Punta arenas, CL
# 7. Processing data for Mahebourg, MU
# 8. Processing data for Thompson, CA
# 9. Processing data for Moyale, KE
# 10. Processing data for Port alfred, ZA
# 11. Processing data for Vila, PT
# 12. Processing data for Tuktoyaktuk, CA
# 13. Processing data for Georgetown, MY
# 14. Processing data for Tasiilaq, GL
# 15. Processing data for Hithadhoo, MV
# 16. Processing data for Ushuaia, AR
# 17. Processing data for Ancud, CL
# 18. Processing data for Atuona, PF
# 19. Processing data for Turayf, SA
# 20. Processing data for Lorengau, PG
# 21. Processing data for Ponta do sol, PT
# 22. Processing data for Dikson, RU
# 23. Processing data for Juneau, US
# 24. Processing data for Sitka, US
# 25. Processing data for Teahupoo, PF
# 26. Processing data for Airai, TL
# 27. Processing data for Vaini, TO
#
# 28. City - Tasbuget is not found! Skipping.....
#
# 29. Processing data for Egvekinot, RU
# 30. Processing data for Avarua, CK
# 31. Processing data for Bambous virieux, MU
# 32. Processing data for Lebu, CL
# 33. Processing data for Pontianak, ID
# 34. Processing data for Broome, US
# 35. Processing data for Hobart, AU
# 36. Processing data for Chuy, UY
# 37. Processing data for Kapaa, US
# 38. Processing data for North bend, US
# 39. Processing data for Noumea, NC
# 40. Processing data for Klaksvik, FO
# 41. Processing data for Nyrob, RU
# 42. Processing data for Severo-kurilsk, RU
# 43. Processing data for Cockburn town, TC
# 44. Processing data for Casablanca, MA
# 45. Processing data for Saint-francois, FR
# 46. Processing data for Bathsheba, BB
# 47. Processing data for Ugoofaaru, MV
# 48. Processing data for Mataura, NZ
# 49. Processing data for Cape town, ZA
# 50. Processing data for Aykhal, RU
# 51. Processing data for Saint-philippe, RE
# 52. Processing data for Rikitea, PF
# 53. Processing data for Yellowknife, CA
# 54. Processing data for Jamestown, US
# 55. Processing data for Jinchang, CN
# 56. Processing data for Capao bonito, BR
# 57. Processing data for Tual, ID
#
# 58. City - Taolanaro is not found! Skipping.....
#
# 59. Processing data for Beloha, MG
# 60. Processing data for Puerto ayora, EC
#
# 61. City - Barentsburg is not found! Skipping.....
#
# 62. Processing data for Cherskiy, RU
# 63. Processing data for Barrow, US
# 64. Processing data for Matagami, CA
# 65. Processing data for Qaanaaq, GL
# 66. Processing data for Katsuura, JP
# 67. Processing data for Chokurdakh, RU
# 68. Processing data for Alofi, NU
# 69. Processing data for Santa maria, BR
# 70. Processing data for Dhidhdhoo, MV
# 71. Processing data for Busselton, AU
# 72. Processing data for Mount isa, AU
# 73. Processing data for Lac du bonnet, CA
# 74. Processing data for Constitucion, CL
# 75. Processing data for Bonoua, CI
# 76. Processing data for Taoudenni, ML
# 77. Processing data for Lucapa, AO
# 78. Processing data for Bredasdorp, ZA
# 79. Processing data for Vila velha, BR
# 80. Processing data for Cabo san lucas, MX
# 81. Processing data for Itaueira, BR
# 82. Processing data for Taltal, CL
# 83. Processing data for Lowicz, PL
# 84. Processing data for Dunedin, NZ
#
# 85. City - Tsihombe is not found! Skipping.....
#
#
# 86. City - Belushya guba is not found! Skipping.....
#
# 87. Processing data for Los llanos de aridane, ES
# 88. Processing data for Hilo, US
# 89. Processing data for Bengkulu, ID
# 90. Processing data for Aksu, CN
# 91. Processing data for Bose, IT
# 92. Processing data for Sorland, NO
# 93. Processing data for Vardo, NO
#
# 94. City - Fort saint john is not found! Skipping.....
#
# 95. Processing data for Tianpeng, CN
# 96. Processing data for Geraldton, AU
# 97. Processing data for Pasni, PK
# 98. Processing data for Antofagasta, CL
#
# 99. City - Samusu is not found! Skipping.....
#
# 100. Processing data for Ostrovnoy, RU
# 101. Processing data for Manokwari, ID
# 102. Processing data for Mar del plata, AR
# 103. Processing data for Nkayi, CG
# 104. Processing data for Kutum, SD
# 105. Processing data for Kokopo, PG
# 106. Processing data for Lahti, RU
#
# 107. City - Nizhneyansk is not found! Skipping.....
#
# 108. Processing data for Vila franca do campo, PT
# 109. Processing data for Touros, BR
# 110. Processing data for Hofn, IS
#
# 111. City - Felidhoo is not found! Skipping.....
#
# 112. Processing data for Faanui, PF
# 113. Processing data for Albany, US
# 114. Processing data for Asau, RO
# 115. Processing data for Codrington, AU
#
# 116. City - Amderma is not found! Skipping.....
#
# 117. Processing data for Torbay, CA
# 118. Processing data for Sovetskiy, RU
# 119. Processing data for Havoysund, NO
# 120. Processing data for Rawson, AR
#
# 121. City - Talawdi is not found! Skipping.....
#
#
# 122. City - Umzimvubu is not found! Skipping.....
#
#
# 123. City - Palabuhanratu is not found! Skipping.....
#
# 124. Processing data for Iqaluit, CA
# 125. Processing data for Opaka, BG
# 126. Processing data for Narsaq, GL
# 127. Processing data for Nuristan, AF
# 128. Processing data for Sambava, MG
# 129. Processing data for Impfondo, CG
# 130. Processing data for Vao, NC
# 131. Processing data for Longyearbyen, SJ
# 132. Processing data for Butaritari, KI
#
# 133. City - Illoqqortoormiut is not found! Skipping.....
#
# 134. Processing data for Atar, MR
# 135. Processing data for Vanavara, RU
# 136. Processing data for College, US
# 137. Processing data for Kuandian, CN
# 138. Processing data for Jiayuguan, CN
#
# 139. City - Saleaula is not found! Skipping.....
#
# 140. Processing data for Clyde river, CA
# 141. Processing data for Nanortalik, GL
# 142. Processing data for San martin, AR
# 143. Processing data for Ban nahin, LA
# 144. Processing data for Cizre, TR
# 145. Processing data for Roald, NO
# 146. Processing data for Margate, GB
# 147. Processing data for Yar-sale, RU
# 148. Processing data for Itoman, JP
# 149. Processing data for Lompoc, US
#
# 150. City - Marv dasht is not found! Skipping.....
#
# 151. Processing data for Barcelona, ES
# 152. Processing data for Mudgee, AU
# 153. Processing data for Avera, US
# 154. Processing data for Bethel, US
# 155. Processing data for Nador, MA
# 156. Processing data for Ribeira grande, PT
# 157. Processing data for Hermanus, ZA
# 158. Processing data for Saskylakh, RU
# 159. Processing data for Onega, RU
# 160. Processing data for Mercedes, AR
# 161. Processing data for Kamaishi, JP
# 162. Processing data for Port-cartier, CA
# 163. Processing data for Ginda, IN
# 164. Processing data for Edson, CA
#
# 165. City - Gurskoye is not found! Skipping.....
#
# 166. Processing data for Sterlibashevo, RU
# 167. Processing data for Leningradskiy, RU
# 168. Processing data for Tabuny, RU
# 169. Processing data for Arraial do cabo, BR
# 170. Processing data for Kavaratti, IN
# 171. Processing data for Joshimath, IN
# 172. Processing data for Poya, NC
# 173. Processing data for Latung, PH
#
# 174. City - Tidore is not found! Skipping.....
#
# 175. Processing data for Derzhavinsk, KZ
#
# 176. City - Grand centre is not found! Skipping.....
#
# 177. Processing data for Si sa ket, TH
# 178. Processing data for Straumen, NO
# 179. Processing data for Port elizabeth, ZA
# 180. Processing data for Boa vista, BR
# 181. Processing data for Souillac, MU
#
# 182. City - Lolua is not found! Skipping.....
#
# 183. Processing data for Juba, SS
# 184. Processing data for Flinders, AU
# 185. Processing data for Jalu, LY
# 186. Processing data for Port lincoln, AU
# 187. Processing data for Hirna, ET
# 188. Processing data for Dhekiajuli, IN
# 189. Processing data for Matongo, TZ
# 190. Processing data for Namibe, AO
# 191. Processing data for Tuatapere, NZ
# 192. Processing data for Luanda, AO
# 193. Processing data for Gisborne, NZ
# 194. Processing data for Hornepayne, CA
# 195. Processing data for Namatanai, PG
#
# 196. City - Kerteh is not found! Skipping.....
#
# 197. Processing data for Taicheng, CN
# 198. Processing data for Portalegre, PT
#
# 199. City - Tawkar is not found! Skipping.....
#
# 200. Processing data for Pechenga, RU
# 201. Processing data for Anadyr, RU
# 202. Processing data for Guerrero negro, MX
# 203. Processing data for Dong hoi, VN
# 204. Processing data for East london, ZA
# 205. Processing data for Hay river, CA
# 206. Processing data for Saint george, US
# 207. Processing data for Uruzgan, AF
# 208. Processing data for Kiknur, RU
# 209. Processing data for Mayo, US
# 210. Processing data for Khatanga, RU
# 211. Processing data for Nome, US
# 212. Processing data for Adrar, MR
#
# 213. City - Paradwip is not found! Skipping.....
#
#
# 214. City - Grand river south east is not found! Skipping.....
#
# 215. Processing data for Kargasok, RU
# 216. Processing data for Yahotyn, UA
# 217. Processing data for Salyan, AZ
# 218. Processing data for Okhotsk, RU
# 219. Processing data for Tessalit, ML
# 220. Processing data for Mwinilunga, ZM
# 221. Processing data for Upernavik, GL
#
# 222. City - Barawe is not found! Skipping.....
#
# 223. Processing data for Longido, TZ
# 224. Processing data for Neuquen, AR
# 225. Processing data for Pochutla, MX
# 226. Processing data for Yuanli, TW
# 227. Processing data for Lazaro cardenas, MX
# 228. Processing data for Pangkalanbuun, ID
# 229. Processing data for Provideniya, RU
# 230. Processing data for Naze, JP
# 231. Processing data for Arrifes, PT
# 232. Processing data for Sao joao da barra, BR
# 233. Processing data for Bestobe, KZ
# 234. Processing data for Zambezi, ZM
#
# 235. City - Tumannyy is not found! Skipping.....
#
#
# 236. City - Stoyba is not found! Skipping.....
#
# 237. Processing data for Pisco, PE
# 238. Processing data for Vestmannaeyjar, IS
# 239. Processing data for Manicore, BR
# 240. Processing data for Neyshabur, IR
# 241. Processing data for Komsomolets, KZ
# 242. Processing data for Suchitoto, SV
# 243. Processing data for Caronport, CA
# 244. Processing data for Grindavik, IS
# 245. Processing data for San jose, US
# 246. Processing data for Ishigaki, JP
# 247. Processing data for Muravlenko, RU
# 248. Processing data for Pevek, RU
#
# 249. City - Attawapiskat is not found! Skipping.....
#
# 250. Processing data for Jacqueville, CI
# 251. Processing data for Takayama, JP
# 252. Processing data for Lavrentiya, RU
# 253. Processing data for Carnarvon, AU
# 254. Processing data for Calabozo, VE
# 255. Processing data for Xuddur, SO
# 256. Processing data for Hasaki, JP
# 257. Processing data for Arkhipo-osipovka, RU
# 258. Processing data for San patricio, MX
#
# 259. City - Pilao arcado is not found! Skipping.....
#
# 260. Processing data for Halmstad, SE
# 261. Processing data for Itaituba, BR
# 262. Processing data for Singaraja, ID
# 263. Processing data for Cayenne, GF
# 264. Processing data for Kyabram, AU
# 265. Processing data for North battleford, CA
# 266. Processing data for Bilma, NE
# 267. Processing data for Vangaindrano, MG
# 268. Processing data for Mucurapo, TT
# 269. Processing data for Ca mau, VN
# 270. Processing data for Kastamonu, TR
# 271. Processing data for Oistins, BB
# 272. Processing data for Arman, RU
# 273. Processing data for Tazovskiy, RU
# 274. Processing data for Valparaiso, CL
# 275. Processing data for Iowa city, US
# 276. Processing data for Kjollefjord, NO
# 277. Processing data for Rio claro, BR
# 278. Processing data for Bredy, RU
# 279. Processing data for Marsa matruh, EG
# 280. Processing data for San vicente, AR
# 281. Processing data for Ilulissat, GL
#
# 282. City - Sentyabrskiy is not found! Skipping.....
#
# 283. Processing data for Husavik, IS
# 284. Processing data for Naliya, IN
# 285. Processing data for Hudson bay, CA
# 286. Processing data for Dumbraveni, RO
# 287. Processing data for Omboue, GA
# 288. Processing data for Piacabucu, BR
# 289. Processing data for Orange, US
# 290. Processing data for Puerto baquerizo moreno, EC
# 291. Processing data for Ayan, RU
# 292. Processing data for Chalus, IR
# 293. Processing data for Esperance, AU
# 294. Processing data for Bar harbor, US
# 295. Processing data for Kaeo, NZ
#
# 296. City - Meinung is not found! Skipping.....
#
# 297. Processing data for Decatur, US
# 298. Processing data for Walvis bay, NA
# 299. Processing data for Laguna, US
# 300. Processing data for La brea, HN
#
# 301. City - Meyungs is not found! Skipping.....
#
# 302. Processing data for Pangody, RU
# 303. Processing data for Yulara, AU
#
# 304. City - Ijaki is not found! Skipping.....
#
# 305. Processing data for Kaitangata, NZ
# 306. Processing data for Praia da vitoria, PT
# 307. Processing data for Awbari, LY
# 308. Processing data for Payson, US
# 309. Processing data for Luderitz, NA
# 310. Processing data for Padang, ID
# 311. Processing data for Necochea, AR
# 312. Processing data for Chipoka, MW
# 313. Processing data for Comodoro rivadavia, AR
# 314. Processing data for Ahipara, NZ
# 315. Processing data for Brae, GB
# 316. Processing data for Narrabri, AU
# 317. Processing data for Boundiali, CI
# 318. Processing data for Gat, IL
#
# 319. City - Safaqis is not found! Skipping.....
#
# 320. Processing data for Victoria, HK
# 321. Processing data for Muhos, FI
# 322. Processing data for Aklavik, CA
# 323. Processing data for Tabas, IR
# 324. Processing data for Belmonte, BR
# 325. Processing data for Batagay-alyta, RU
# 326. Processing data for Guane, CU
# 327. Processing data for Boshnyakovo, RU
# 328. Processing data for Shakiso, ET
# 329. Processing data for Wairoa, NZ
# 330. Processing data for Meridian, US
# 331. Processing data for Alta floresta, BR
# 332. Processing data for Hegra, NO
# 333. Processing data for Senneterre, CA
# 334. Processing data for Mehamn, NO
# 335. Processing data for Komsomolskiy, UZ
# 336. Processing data for Scarborough, GB
# 337. Processing data for Palora, EC
# 338. Processing data for Tsabong, BW
# 339. Processing data for Port hedland, AU
# 340. Processing data for Tateyama, JP
# 341. Processing data for Picui, BR
# 342. Processing data for Bubaque, GW
# 343. Processing data for Saint anthony, US
# 344. Processing data for Yenagoa, NG
# 345. Processing data for Kenai, US
# 346. Processing data for Fortuna, US
# 347. Processing data for Yebaishou, CN
# 348. Processing data for Wake forest, US
# 349. Processing data for Narasannapeta, IN
# 350. Processing data for Alihe, CN
# 351. Processing data for Nicoya, CR
# 352. Processing data for Aktau, KZ
# 353. Processing data for Togur, RU
# 354. Processing data for Te anau, NZ
# 355. Processing data for Caravelas, BR
# 356. Processing data for Nishihara, JP
# 357. Processing data for Tygda, RU
# 358. Processing data for Dashitou, CN
# 359. Processing data for Beoumi, CI
# 360. Processing data for Tecoanapa, MX
# 361. Processing data for San cristobal, VE
# 362. Processing data for Benjamin constant, BR
# 363. Processing data for Lakes entrance, AU
# 364. Processing data for Lagoa, PT
# 365. Processing data for Tiksi, RU
# 366. Processing data for Isangel, VU
# 367. Processing data for Matara, LK
# 368. Processing data for Adelaide, AU
# 369. Processing data for Ust-kuyga, RU
# 370. Processing data for Puerto carreno, CO
# 371. Processing data for Hambantota, LK
# 372. Processing data for Hamilton, US
#
# 373. City - Armacao dos buzios is not found! Skipping.....
#
# 374. Processing data for Abeche, TD
# 375. Processing data for Sheregesh, RU
# 376. Processing data for Poum, NC
# 377. Processing data for Kununurra, AU
# 378. Processing data for Saldanha, ZA
# 379. Processing data for Sola, VU
# 380. Processing data for Eureka, US
# 381. Processing data for Ust-tsilma, RU
# 382. Processing data for Myanaung, MM
# 383. Processing data for Macapa, BR
# 384. Processing data for Boyolangu, ID
# 385. Processing data for Deputatskiy, RU
# 386. Processing data for Mecca, SA
# 387. Processing data for Oranjestad, AW
# 388. Processing data for Qinzhou, CN
# 389. Processing data for Norman wells, CA
# 390. Processing data for Borgarnes, IS
# 391. Processing data for Sakakah, SA
#
# 392. City - Tsienyane is not found! Skipping.....
#
# 393. Processing data for Nyurba, RU
#
# 394. City - Mentok is not found! Skipping.....
#
# 395. Processing data for Orange cove, US
# 396. Processing data for Tiznit, MA
# 397. Processing data for Ponca city, US
# 398. Processing data for Pecos, US
# 399. Processing data for Potsdam, DE
# 400. Processing data for Babu, CN
# 401. Processing data for Tura, IN
# 402. Processing data for Ambilobe, MG
# 403. Processing data for Aripuana, BR
# 404. Processing data for Kuytun, RU
# 405. Processing data for Tutoia, BR
# 406. Processing data for Gazipur, BD
# 407. Processing data for Hirara, JP
# 408. Processing data for Havre-saint-pierre, CA
# 409. Processing data for Traverse city, US
# 410. Processing data for Dzhebariki-khaya, RU
# 411. Processing data for Wanning, CN
# 412. Processing data for Cidreira, BR
# 413. Processing data for Tilichiki, RU
# 414. Processing data for Mansfield, GB
# 415. Processing data for San juan, AR
# 416. Processing data for Sayanogorsk, RU
# 417. Processing data for Mana, GF
# 418. Processing data for Nisia floresta, BR
# 419. Processing data for Coihaique, CL
# 420. Processing data for Batemans bay, AU
# 421. Processing data for Orsha, BY
# 422. Processing data for Bonavista, CA
# 423. Processing data for Sept-iles, CA
# 424. Processing data for Launceston, AU
#
# 425. City - Mys shmidta is not found! Skipping.....
#
# 426. Processing data for Buhe, CN
# 427. Processing data for Pringsewu, ID
# 428. Processing data for Alanya, TR
# 429. Processing data for Safaga, EG
# 430. Processing data for Pacific grove, US
# 431. Processing data for Santiago, CL
#
# 432. City - Riyaq is not found! Skipping.....
#
# 433. Processing data for Santa cruz, BO
# 434. Processing data for Zlocieniec, PL
# 435. Processing data for Coquimbo, CL
# 436. Processing data for Naifaru, MV
# 437. Processing data for Tazmalt, DZ
# 438. Processing data for La macarena, CO
# 439. Processing data for Inuvik, CA
# 440. Processing data for Dukat, RU
# 441. Processing data for Mogadishu, SO
# 442. Processing data for Hailar, CN
# 443. Processing data for Broken hill, AU
# 444. Processing data for Monrovia, LR
#
# 445. City - Sumbawa is not found! Skipping.....
#
# 446. Processing data for Tirumullaivasal, IN
# 447. Processing data for Novikovo, RU
# 448. Processing data for Imbituba, BR
# 449. Processing data for Tuban, ID
# 450. Processing data for Prince rupert, CA
#
# 451. City - Aflu is not found! Skipping.....
#
# 452. Processing data for Tulum, MX
# 453. Processing data for Yinchuan, CN
# 454. Processing data for Sangar, RU
# 455. Processing data for Sistranda, NO
# 456. Processing data for Malartic, CA
# 457. Processing data for Kurchum, KZ
# 458. Processing data for Korla, CN
# 459. Processing data for Harqalah, TN
# 460. Processing data for Saint-joseph, RE
# 461. Processing data for Berlevag, NO
#
# 462. City - Marcona is not found! Skipping.....
#
# 463. Processing data for Chumikan, RU
#
# 464. City - Phumi samraong is not found! Skipping.....
#
# 465. Processing data for Terekli-mekteb, RU
#
# 466. City - Bur gabo is not found! Skipping.....
#
# 467. Processing data for Ascension, US
# 468. Processing data for Alugan, PH
# 469. Processing data for Muroto, JP
# 470. Processing data for Hobyo, SO
# 471. Processing data for Karasjok, NO
# 472. Processing data for Mirandopolis, BR
#
# 473. City - Zyryanovskiy is not found! Skipping.....
#
# 474. Processing data for Ihosy, MG
# 475. Processing data for Kahului, US
# 476. Processing data for Chincha alta, PE
# 477. Processing data for Camargo, MX
# 478. Processing data for Remedios, CU
# 479. Processing data for Boditi, ET
# 480. Processing data for Dwarka, IN
# 481. Processing data for Ormara, PK
# 482. Processing data for Mount gambier, AU
# 483. Processing data for Lira, UG
# 484. Processing data for Olinda, BR
# 485. Processing data for Terra rica, BR
#
# 486. City - Wulanhaote is not found! Skipping.....
#
#
# 487. City - Kidal is not found! Skipping.....
#
#
# 488. City - Chagda is not found! Skipping.....
#
# 489. Processing data for Adre, TD
# 490. Processing data for Paamiut, GL
#
# 491. City - Thano bula khan is not found! Skipping.....
#
# 492. Processing data for Karlstad, SE
# 493. Processing data for Zaozerne, UA
# 494. Processing data for Brookhaven, US
# 495. Processing data for Lehigh acres, US
# 496. Processing data for Kavieng, PG
# 497. Processing data for Ketchikan, US
# 498. Processing data for Kloulklubed, PW
# 499. Processing data for Monroe, US
# 500. Processing data for Mason city, US
# 501. Processing data for Viedma, AR
# 502. Processing data for Jaca, ES
# 503. Processing data for Rocha, UY
# 504. Processing data for Srednekolymsk, RU
# 505. Processing data for Gouyave, GD
# 506. Processing data for Pemangkat, ID
# 507. Processing data for Tucurui, BR
# 508. Processing data for Estacion coahuila, MX
# 509. Processing data for Westport, US
# 510. Processing data for Beringovskiy, RU
# 511. Processing data for Banikoara, BJ
# 512. Processing data for Abu zabad, SD
# 513. Processing data for Kerman, IR
# 514. Processing data for Rudbar, AF
# 515. Processing data for Shingu, JP
# 516. Processing data for Axim, GH
# 517. Processing data for Hohhot, CN
#
# ^^^^^^^^^^^^^^^^^^^^^^^^
# Data Retrieval Complete
#
# ^^^^^^^^^^^^^^^^^^^^^^^^

# %% [markdown]
# ### Convert Raw Data to DataFrame
#
# * Display the DataFrame
# * Export the city data into a .csv.

# %%
# Convert the data into Pandas DataFrame
Cities_Data_df = pd.DataFrame(Cities_Data)

# Output File (CSV)
#output_data_file = "../output_data/cities.csv"

# Export the City_Data into a csv
#Cities_Data_df.to_csv(output_data_file, index_label="City_ID")

Cities_Data_df
# Out:
#             City Country  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0         Castro      BR    -24.79     -50.01     69.49        34           0
# 1          Bluff      NZ    -46.60     168.33     48.06        72           1
# 2        Talnakh      RU     69.49      88.40     15.80        85           0
# 3    New norfolk      AU    -42.78     147.06     45.00        90          60
# 4     Nikolskoye      RU     59.70      30.79     48.00        93          90
# ..           ...     ...       ...        ...       ...       ...         ...
# 464       Kerman      IR     30.28      57.08     66.20        17           0
# 465       Rudbar      AF     30.15      62.60     86.40        19           0
# 466       Shingu      JP     33.73     135.98     61.86        86           0
# 467         Axim      GH      4.87      -2.24     81.88        83          96
# 468       Hohhot      CN     40.81     111.65     50.00        37           0
#
#      Wind Speed
# 0          3.87
# 1         24.87
# 2         38.03
# 3          2.82
# 4          2.24
# ..          ...
# 464        6.93
# 465        4.90
# 466        4.79
# 467        6.60
# 468        6.71
#
# [469 rows x 8 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
# Extract relevant fields from the data frame

Latitudes = Cities_Data_df["Latitude"]
Longitudes = Cities_Data_df["Longitude"]
Temperatures = Cities_Data_df["Max Temp"]
Humudities = Cities_Data_df["Humidity"]
Cloudiness = Cities_Data_df["Cloudiness"]
Wind_speeds = Cities_Data_df["Wind Speed"]

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
from matplotlib import style
style.use('seaborn')

# Build a scatter plot for latitude vs. temperature

plt.figure(figsize=(9, 6))

plt.scatter(Latitudes, 
            Temperatures,
            facecolors = "blue",
            marker="o",
            edgecolor="k",
            linewidths=1,  
            alpha=0.75,
            label="Cities"
           )

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"), 
          color = "darkblue", fontsize = 17, pad = 20)

plt.xlabel("Latitude", color = "darkblue", fontsize = 15)
plt.ylabel("Max Temperature (F)", color = "darkblue", fontsize = 15)


plt.grid(True)

# Save the figure
plt.savefig("images/LatVsTemp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for latitude vs. temperature

plt.figure(figsize=(9,6))

plt.scatter(Latitudes, 
            Humudities,
            facecolors = "b",
            marker="o",
            edgecolor="k",
            linewidths=1,  
            alpha=0.75,
            label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"), 
          color = "darkblue", 
          fontsize = 17, 
          pad = 20)

plt.xlabel("Latitude", color = "darkblue", fontsize = 15)
plt.ylabel("Humidity (%)", color = "darkblue", fontsize = 15)

plt.grid(True)

# Save the figure
plt.savefig("images/LatVsHumidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for latitude vs. temperature

plt.figure(figsize=(9,6), dpi=80)

plt.scatter(Latitudes, 
            Cloudiness,
            facecolors = "blue",
            marker="o",
            edgecolor="k",
            linewidths=1,  
            alpha=0.75,
            label="Cities")

# Incorporate the other graph properties

plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"), color = "darkblue", fontsize = 17, pad = 20)

plt.xlabel("Latitude", color = "darkblue", fontsize = 15)
plt.ylabel("Cloudiness (%)", color = "darkblue", fontsize = 15)

plt.grid(True)

# Save the figure
plt.savefig("images/LatVsCloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for latitude vs. temperature


plt.figure(figsize=(9,6), dpi=80)

plt.scatter(Latitudes, 
            Wind_speeds,
            marker="o",
            facecolors = "b",
            edgecolor="k",
            linewidths=1,  
            alpha=0.75,
            label="Cities")

# Incorporate the other graph properties

plt.title("Latitude vs. Wind Speed (%s)" % time.strftime("%x"), color = "darkblue", fontsize = 17, pad = 20)

plt.xlabel("Latitude", color = "darkblue", fontsize = 15)
plt.ylabel("Wind Speed", color = "darkblue", fontsize = 15)

plt.grid(True)

# Save the figure

plt.savefig("images/LatVsWindSpeed.png")

# Show plot

plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

def linear_reg_plot(x_values, y_values, title, x_label, y_label, line_eq_coord):

    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    regress_values = x_values * slope + intercept
    
    # Build the equation y = mx + c

    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Build a scatter plot for the relevant fields
    
    plt.figure(figsize=(9,6))
    
    plt.scatter(x_values,y_values,
                facecolors = "blue",
                marker="o",
                edgecolor="darkblue",
                linewidths=1,  
                alpha=0.75)
    
    plt.plot(x_values,regress_values,"g-")
    
    # Incorporate the other graph properties
    
    plt.title(title, color = "darkblue", fontsize = 18, pad = 20)
    
    plt.xlabel(x_label, color = "darkblue", fontsize = 15)
    plt.ylabel(y_label, color = "darkblue", fontsize = 15)
    
    # Display the line equation on the map
    
    plt.annotate(line_eq, line_eq_coord, fontsize = 18, color = "darkblue")

    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
Northern_hemi_df = Cities_Data_df.loc[Cities_Data_df['Latitude']>=0]
Northern_hemi_df
# Out:
#            City Country  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 2       Talnakh      RU     69.49      88.40     15.80        85           0
# 4    Nikolskoye      RU     59.70      30.79     48.00        93          90
# 5    Lypnyazhka      UA     48.45      31.08     59.58        70           9
# 8      Thompson      CA     55.74     -97.86     44.60        36          20
# 9        Moyale      KE      3.52      39.06     68.27        60          21
# ..          ...     ...       ...        ...       ...       ...         ...
# 464      Kerman      IR     30.28      57.08     66.20        17           0
# 465      Rudbar      AF     30.15      62.60     86.40        19           0
# 466      Shingu      JP     33.73     135.98     61.86        86           0
# 467        Axim      GH      4.87      -2.24     81.88        83          96
# 468      Hohhot      CN     40.81     111.65     50.00        37           0
#
#      Wind Speed
# 2         38.03
# 4          2.24
# 5          2.59
# 8          4.70
# 9          3.29
# ..          ...
# 464        6.93
# 465        4.90
# 466        4.79
# 467        6.60
# 468        6.71
#
# [323 rows x 8 columns]

# %%
Southern_hemi_df = Cities_Data_df.loc[Cities_Data_df['Latitude']<0]
Southern_hemi_df
# Out:
#              City Country  Latitude  Longitude  Max Temp  Humidity  \
# 0          Castro      BR    -24.79     -50.01     69.49        34
# 1           Bluff      NZ    -46.60     168.33     48.06        72
# 3     New norfolk      AU    -42.78     147.06     45.00        90
# 6    Punta arenas      CL    -53.15     -70.92     48.20        57
# 7       Mahebourg      MU    -20.41      57.70     75.20        83
# ..            ...     ...       ...        ...       ...       ...
# 440    Terra rica      BR    -22.71     -52.62     79.97        43
# 447       Kavieng      PG     -2.57     150.80     82.71        83
# 452        Viedma      AR    -40.81     -63.00     59.50        53
# 454         Rocha      UY    -34.48     -54.33     65.39        71
# 458       Tucurui      BR     -3.77     -49.67     86.79        69
#
#      Cloudiness  Wind Speed
# 0             0        3.87
# 1             1       24.87
# 3            60        2.82
# 6            15       11.41
# 7            40        8.05
# ..          ...         ...
# 440          17        4.81
# 447          66       11.36
# 452         100       10.11
# 454         100        2.95
# 458           7        3.91
#
# [146 rows x 8 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear_reg_plot(Northern_hemi_df["Latitude"],
                Northern_hemi_df["Max Temp"],
                "Northern Hemisphere: Latitude vs. Max Temp",
                "Latitude",
                "Max Temp",
                (60,60))

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear_reg_plot(Southern_hemi_df["Latitude"],
                Southern_hemi_df["Max Temp"],
                "Southern Hemisphere: Latitude vs. Max Temp",
                "Latitude",
                "Max Temp",
                (-20,50))

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_reg_plot(Northern_hemi_df["Latitude"],
                Northern_hemi_df["Humidity"],
                "Northern Hemisphere: Latitude vs. Humidity",
                "Latitude",
                "Humidity",
                (50,20))

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_reg_plot(Southern_hemi_df["Latitude"],
                Southern_hemi_df["Humidity"],
                "Southern Hemisphere: Latitude vs. Humidity",
                "Latitude",
                "Humidity",
                (-12,40))

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_reg_plot(Northern_hemi_df["Latitude"],
                Northern_hemi_df["Cloudiness"],
                "Northern Hemisphere \n Latitude vs. Max Temp",
                "Latitude",
                "Cloudiness",
                (20,60))

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_reg_plot(Southern_hemi_df["Latitude"],
                Southern_hemi_df["Cloudiness"],
                "Southern Hemisphere: Latitude vs. Cloudiness",
                "Latitude",
                "Cloudiness",
                (-20,60))

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_reg_plot(Northern_hemi_df["Latitude"],
                Northern_hemi_df["Wind Speed"],
                "Northern Hemisphere: Latitude vs. Wind Speed",
                "Latitude",
                "Wind Speed",
                (10,25))

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_reg_plot(Southern_hemi_df["Latitude"],
                Southern_hemi_df["Wind Speed"],
                "Southern Hemisphere: Latitude vs. Wind Speed",
                "Latitude",
                "Wind Speed",
                (-56,15))
