# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ## Generate Cities List
# ---

# %%
# Range of latitudes and longitudes

lat_range = (-90, 90)
lng_range = (-180, 180)

# Lists for holding latitudes-longitudes and cities

lat_lngs = []
cities = []

# Create a set of random lat and lng combinations

lats = np.random.uniform(low = -90.000, high = 90.000, size = 1200)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 1200)

lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination

for lat_lng in lat_lngs:
    
    City = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name.capitalize()
    
    # If the city is unique, then add it to cities list
    
    if City not in cities:
        cities.append(City)
        
# Print the city count and cities list

print(f'\n{len(cities)} cities are selected.\n')
print(cities)
# Out:
# 513 cities are selected.
#
# ['Ushuaia', 'Busselton', 'Salalah', 'Muros', 'East london', 'Itupiranga', 'Katsuura', 'Belmonte', 'Pahrump', 'Saldanha', 'Wattegama', 'Port elizabeth', 'Tandil', 'Tessalit', 'Bluff', 'Bandarbeyla', 'Hobart', 'Bud', 'Tasiilaq', 'Punta arenas', 'Klaksvik', 'Karangampel', 'Rikitea', 'Tuktoyaktuk', 'Uruzgan', 'Prado', 'Mataura', 'Saint-philippe', 'Albany', 'Katangli', 'Maningrida', 'Dikson', 'Hithadhoo', 'Bethel', 'Atuona', 'Yellowknife', 'Diego de almagro', 'Pevek', 'Baruun-urt', 'Amderma', 'Kjollefjord', 'Altoona', 'Attawapiskat', 'Mirante do paranapanema', 'Bengkulu', 'Poum', 'Chokurdakh', 'Longyearbyen', 'Gat', 'Kapaa', 'San patricio', 'Yantal', 'Caravelas', 'Dembi dolo', 'Butaritari', 'Torbay', 'Vaini', 'Dubuque', 'Rawlins', 'Mackay', 'Kloulklubed', 'Leningradskiy', 'Mahebourg', 'Bredasdorp', 'Cape town', 'Farafangana', 'Hilo', 'Arraial do cabo', 'Illoqqortoormiut', 'Bambous virieux', 'Fort nelson', 'Faanui', 'Port alfred', 'Palabuhanratu', 'Mar del plata', 'Khatanga', 'Souillac', 'Thompson', 'Requena', 'Havre', 'Sentyabrskiy', 'Belyy yar', 'Taolanaro', 'Saint-pierre', 'Adre', 'Mkuranga', 'Clyde river', 'Norman wells', 'Alta floresta', 'Rocha', 'Ponta delgada', 'Scarborough', 'Ancud', 'Umzimvubu', 'Aleksandrov gay', 'Necochea', 'Kodiak', 'Roald', 'Viedma', 'Alofi', 'Sao joao da barra', 'Urcos', 'Vaitupu', 'Beloha', 'Itarema', 'Nouadhibou', 'Ust-omchug', 'Nikolskoye', 'Hambantota', 'Carnarvon', 'Upernavik', 'Mount gambier', 'Tuzha', 'Urumqi', 'Yarim', 'Belushya guba', 'Isangel', 'Tezu', 'Chara', 'Nanortalik', 'Klobuck', 'New norfolk', 'Yulara', 'Lagoa', 'Hermanus', 'Geraldton', 'Diadi', 'Livingston', 'Puerto ayora', 'Jamestown', 'Aklavik', 'Castro', 'Krasnomayskiy', 'Saleaula', 'Hwange', 'Barrow', 'La sarre', 'Bose', 'Kavieng', 'Labuhan', 'Abapo', 'Makakilo city', 'Bonavista', 'Grindavik', 'Igarka', 'Georgetown', 'Qaanaaq', 'Louisbourg', 'Biloela', 'Kitimat', 'Riyadh', 'Cascais', 'Eston', 'Meulaboh', 'Bac lieu', 'Avarua', 'Pavlovo', 'Luderitz', 'Ewa beach', 'Skiros', 'Kargopol', 'Teshie', 'Desnogorsk', 'Galesong', 'Hasaki', 'Uturoa', 'Jumla', 'Kalmunai', 'Wanning', 'Yuzhno-kurilsk', 'Minab', 'Salinopolis', 'Fairbanks', 'Srandakan', 'Lethem', 'Portland', 'Erenhot', 'Atar', 'Kruisfontein', 'Salinas', 'Ngukurr', 'Bo', 'Nosy varika', 'Monticello', 'Komsomolskiy', 'Korla', 'Broken hill', 'Adrar', 'Narsaq', 'Clearlake', 'Saskylakh', 'Talnakh', 'Klin', 'Ejido', 'Kahului', 'Bima', 'Mys shmidta', 'Senador pompeu', 'Sinnamary', 'Halalo', 'Umea', 'Andenes', 'Codrington', 'Fortuna', 'Ribeira grande', 'Barentsburg', 'Lorengau', 'Ahipara', 'Meyungs', 'Port hedland', 'Luganville', 'Provideniya', 'Acajutla', 'Usinsk', 'Arlit', 'Nome', 'Palmer', 'Rudbar', 'Cabo san lucas', 'Margate', 'Comodoro rivadavia', 'Khani', 'Dudinka', 'Huarmey', 'Van', 'Berlevag', 'Saint-augustin', 'Simao', 'Purpe', 'Srednekolymsk', 'Edd', 'Halifax', 'Kaitangata', 'Marienburg', 'Iqaluit', 'Santa isabel do rio negro', 'Pisco', 'Tumannyy', 'Bazarnyye mataki', 'Roma', 'Pangnirtung', 'Pedasi', 'Bacuit', 'Gao', 'La palma', 'Karauzyak', 'Ahuimanu', 'Asau', 'Kamaishi', 'Iquitos', 'Ijaki', 'Krasnoselkup', 'Kainantu', 'Floro', 'Cap malheureux', 'Sahuaripa', 'Vestmanna', 'Laguna', 'Esperance', 'Soe', 'Mount isa', 'Port lincoln', 'Po', 'Nevsehir', 'The pas', 'Narendranagar', 'Rungata', 'Evensk', 'Samusu', 'Ambilobe', 'Ilulissat', 'Bowen', 'Tiksi', 'Shelburne', 'Cherskiy', 'Lichinga', 'Los llanos de aridane', 'Beringovskiy', 'Severo-kurilsk', 'Saint-georges', 'Saint george', 'Matagami', 'Tunduru', 'Wilmington', 'Manokwari', 'Doctor juan leon mallorquin', 'Brooks', 'Acapulco', 'West fargo', 'Moa', 'Babu', 'Watsa', 'Airai', 'Turukhansk', 'Tolmachevo', 'Haimen', 'Iberia', 'Petropavlovka', 'Kemijarvi', 'Sibu', 'Falmouth', 'Srivardhan', 'Qinhuangdao', 'Manggar', 'Waipawa', 'Pilar', 'Kavaratti', 'Cidreira', 'Naze', 'Valdosta', 'Chapais', 'Namatanai', 'Laukaa', 'Kuhdasht', 'Spencer', 'Linhares', 'Midyat', 'Sfantu gheorghe', 'Chuy', 'Zhigansk', 'Koulikoro', 'Ust-maya', 'Tulle', 'Tuatapere' ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#api.openweathermap.org/data/2.5/weather?q={city name}&appid={your api key}

base_url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&q="


Cities_Data = []


for i, City in enumerate(cities):
    
    query_url = base_url + str(City) + "&appid=" + weather_api_key
    
    try:
        
        data = requests.get(query_url).json()
        
        Country = data['sys']['country']
        
        print(f'{i}. Processing data for {City}, {Country}')
        
        latitude = data["coord"]["lat"]
        
        longitude = data["coord"]["lon"]
        
        temperature = data["main"]["temp_max"]
        
        humidity = data["main"]["humidity"]
        
        Cloudiness = data["clouds"]["all"]
        
        Wind_speed = data["wind"]["speed"]
        
        Cities_Data.append({
                          "City" : City,
                          "Country" : Country,
                          "Latitude" : latitude,
                          "Longitude" : longitude,
                          "Max Temp" : temperature,
                          "Humidity" : humidity,
                          "Cloudiness" : Cloudiness,
                          "Wind Speed" : Wind_speed
                         })
        
    except:
        print(f'\n{i}. City - {City} is not found! Skipping.....\n')
        pass
    
              
# Indicate that Data Loading is complete

print("\n^^^^^^^^^^^^^^^^^^^^^^^^")
print("Data Retrieval Complete      ")
print("\n^^^^^^^^^^^^^^^^^^^^^^^^\n")
# Out:
# 0. Processing data for Ushuaia, AR
# 1. Processing data for Busselton, AU
# 2. Processing data for Salalah, OM
# 3. Processing data for Muros, ES
# 4. Processing data for East london, ZA
# 5. Processing data for Itupiranga, BR
# 6. Processing data for Katsuura, JP
# 7. Processing data for Belmonte, BR
# 8. Processing data for Pahrump, US
#
# 9. City - Saldanha is not found! Skipping.....
#
# 10. Processing data for Wattegama, LK
# 11. Processing data for Port elizabeth, ZA
# 12. Processing data for Tandil, AR
# 13. Processing data for Tessalit, ML
# 14. Processing data for Bluff, NZ
# 15. Processing data for Bandarbeyla, SO
# 16. Processing data for Hobart, AU
# 17. Processing data for Bud, US
# 18. Processing data for Tasiilaq, GL
# 19. Processing data for Punta arenas, CL
# 20. Processing data for Klaksvik, FO
# 21. Processing data for Karangampel, ID
# 22. Processing data for Rikitea, PF
# 23. Processing data for Tuktoyaktuk, CA
# 24. Processing data for Uruzgan, AF
# 25. Processing data for Prado, BR
# 26. Processing data for Mataura, NZ
# 27. Processing data for Saint-philippe, RE
# 28. Processing data for Albany, US
# 29. Processing data for Katangli, RU
# 30. Processing data for Maningrida, AU
# 31. Processing data for Dikson, RU
# 32. Processing data for Hithadhoo, MV
# 33. Processing data for Bethel, US
# 34. Processing data for Atuona, PF
# 35. Processing data for Yellowknife, CA
# 36. Processing data for Diego de almagro, CL
# 37. Processing data for Pevek, RU
# 38. Processing data for Baruun-urt, MN
#
# 39. City - Amderma is not found! Skipping.....
#
# 40. Processing data for Kjollefjord, NO
# 41. Processing data for Altoona, US
#
# 42. City - Attawapiskat is not found! Skipping.....
#
# 43. Processing data for Mirante do paranapanema, BR
# 44. Processing data for Bengkulu, ID
# 45. Processing data for Poum, NC
# 46. Processing data for Chokurdakh, RU
# 47. Processing data for Longyearbyen, SJ
# 48. Processing data for Gat, IL
# 49. Processing data for Kapaa, US
# 50. Processing data for San patricio, MX
# 51. Processing data for Yantal, RU
# 52. Processing data for Caravelas, BR
# 53. Processing data for Dembi dolo, ET
# 54. Processing data for Butaritari, KI
# 55. Processing data for Torbay, CA
# 56. Processing data for Vaini, TO
# 57. Processing data for Dubuque, US
# 58. Processing data for Rawlins, US
# 59. Processing data for Mackay, AU
# 60. Processing data for Kloulklubed, PW
# 61. Processing data for Leningradskiy, RU
# 62. Processing data for Mahebourg, MU
# 63. Processing data for Bredasdorp, ZA
# 64. Processing data for Cape town, ZA
# 65. Processing data for Farafangana, MG
# 66. Processing data for Hilo, US
# 67. Processing data for Arraial do cabo, BR
#
# 68. City - Illoqqortoormiut is not found! Skipping.....
#
# 69. Processing data for Bambous virieux, MU
# 70. Processing data for Fort nelson, CA
# 71. Processing data for Faanui, PF
# 72. Processing data for Port alfred, ZA
#
# 73. City - Palabuhanratu is not found! Skipping.....
#
# 74. Processing data for Mar del plata, AR
# 75. Processing data for Khatanga, RU
# 76. Processing data for Souillac, MU
# 77. Processing data for Thompson, CA
# 78. Processing data for Requena, ES
# 79. Processing data for Havre, FR
#
# 80. City - Sentyabrskiy is not found! Skipping.....
#
# 81. Processing data for Belyy yar, RU
#
# 82. City - Taolanaro is not found! Skipping.....
#
# 83. Processing data for Saint-pierre, RE
# 84. Processing data for Adre, TD
# 85. Processing data for Mkuranga, TZ
# 86. Processing data for Clyde river, CA
# 87. Processing data for Norman wells, CA
# 88. Processing data for Alta floresta, BR
# 89. Processing data for Rocha, UY
# 90. Processing data for Ponta delgada, PT
# 91. Processing data for Scarborough, GB
# 92. Processing data for Ancud, CL
#
# 93. City - Umzimvubu is not found! Skipping.....
#
# 94. Processing data for Aleksandrov gay, RU
# 95. Processing data for Necochea, AR
# 96. Processing data for Kodiak, US
# 97. Processing data for Roald, NO
# 98. Processing data for Viedma, AR
# 99. Processing data for Alofi, NU
# 100. Processing data for Sao joao da barra, BR
# 101. Processing data for Urcos, PE
#
# 102. City - Vaitupu is not found! Skipping.....
#
# 103. Processing data for Beloha, MG
# 104. Processing data for Itarema, BR
# 105. Processing data for Nouadhibou, MR
# 106. Processing data for Ust-omchug, RU
# 107. Processing data for Nikolskoye, RU
# 108. Processing data for Hambantota, LK
# 109. Processing data for Carnarvon, AU
# 110. Processing data for Upernavik, GL
# 111. Processing data for Mount gambier, AU
# 112. Processing data for Tuzha, RU
# 113. Processing data for Urumqi, CN
# 114. Processing data for Yarim, YE
#
# 115. City - Belushya guba is not found! Skipping.....
#
# 116. Processing data for Isangel, VU
# 117. Processing data for Tezu, IN
# 118. Processing data for Chara, RU
# 119. Processing data for Nanortalik, GL
# 120. Processing data for Klobuck, PL
# 121. Processing data for New norfolk, AU
# 122. Processing data for Yulara, AU
# 123. Processing data for Lagoa, PT
# 124. Processing data for Hermanus, ZA
# 125. Processing data for Geraldton, AU
# 126. Processing data for Diadi, PH
# 127. Processing data for Livingston, GB
# 128. Processing data for Puerto ayora, EC
# 129. Processing data for Jamestown, US
# 130. Processing data for Aklavik, CA
# 131. Processing data for Castro, BR
# 132. Processing data for Krasnomayskiy, RU
#
# 133. City - Saleaula is not found! Skipping.....
#
# 134. Processing data for Hwange, ZW
# 135. Processing data for Barrow, US
# 136. Processing data for La sarre, CA
# 137. Processing data for Bose, IT
# 138. Processing data for Kavieng, PG
# 139. Processing data for Labuhan, ID
# 140. Processing data for Abapo, BO
# 141. Processing data for Makakilo city, US
# 142. Processing data for Bonavista, CA
# 143. Processing data for Grindavik, IS
# 144. Processing data for Igarka, RU
# 145. Processing data for Georgetown, MY
# 146. Processing data for Qaanaaq, GL
#
# 147. City - Louisbourg is not found! Skipping.....
#
# 148. Processing data for Biloela, AU
# 149. Processing data for Kitimat, CA
# 150. Processing data for Riyadh, SA
# 151. Processing data for Cascais, PT
# 152. Processing data for Eston, CA
# 153. Processing data for Meulaboh, ID
# 154. Processing data for Bac lieu, VN
# 155. Processing data for Avarua, CK
# 156. Processing data for Pavlovo, RU
# 157. Processing data for Luderitz, NA
# 158. Processing data for Ewa beach, US
#
# 159. City - Skiros is not found! Skipping.....
#
# 160. Processing data for Kargopol, RU
# 161. Processing data for Teshie, GH
# 162. Processing data for Desnogorsk, RU
# 163. Processing data for Galesong, ID
# 164. Processing data for Hasaki, JP
# 165. Processing data for Uturoa, PF
# 166. Processing data for Jumla, NP
# 167. Processing data for Kalmunai, LK
# 168. Processing data for Wanning, CN
# 169. Processing data for Yuzhno-kurilsk, RU
# 170. Processing data for Minab, IR
# 171. Processing data for Salinopolis, BR
# 172. Processing data for Fairbanks, US
# 173. Processing data for Srandakan, ID
# 174. Processing data for Lethem, GY
# 175. Processing data for Portland, US
# 176. Processing data for Erenhot, CN
# 177. Processing data for Atar, MR
# 178. Processing data for Kruisfontein, ZA
# 179. Processing data for Salinas, US
#
# 180. City - Ngukurr is not found! Skipping.....
#
#
# 181. City - Bo is not found! Skipping.....
#
# 182. Processing data for Nosy varika, MG
# 183. Processing data for Monticello, US
# 184. Processing data for Komsomolskiy, UZ
# 185. Processing data for Korla, CN
# 186. Processing data for Broken hill, AU
# 187. Processing data for Adrar, MR
# 188. Processing data for Narsaq, GL
# 189. Processing data for Clearlake, US
# 190. Processing data for Saskylakh, RU
# 191. Processing data for Talnakh, RU
# 192. Processing data for Klin, RU
# 193. Processing data for Ejido, VE
# 194. Processing data for Kahului, US
# 195. Processing data for Bima, ID
#
# 196. City - Mys shmidta is not found! Skipping.....
#
# 197. Processing data for Senador pompeu, BR
# 198. Processing data for Sinnamary, GF
#
# 199. City - Halalo is not found! Skipping.....
#
# 200. Processing data for Umea, SE
# 201. Processing data for Andenes, NO
# 202. Processing data for Codrington, AU
# 203. Processing data for Fortuna, US
# 204. Processing data for Ribeira grande, PT
#
# 205. City - Barentsburg is not found! Skipping.....
#
# 206. Processing data for Lorengau, PG
# 207. Processing data for Ahipara, NZ
#
# 208. City - Meyungs is not found! Skipping.....
#
# 209. Processing data for Port hedland, AU
# 210. Processing data for Luganville, VU
# 211. Processing data for Provideniya, RU
# 212. Processing data for Acajutla, SV
# 213. Processing data for Usinsk, RU
# 214. Processing data for Arlit, NE
# 215. Processing data for Nome, US
# 216. Processing data for Palmer, US
# 217. Processing data for Rudbar, AF
# 218. Processing data for Cabo san lucas, MX
# 219. Processing data for Margate, GB
# 220. Processing data for Comodoro rivadavia, AR
# 221. Processing data for Khani, GE
# 222. Processing data for Dudinka, RU
# 223. Processing data for Huarmey, PE
# 224. Processing data for Van, TR
# 225. Processing data for Berlevag, NO
# 226. Processing data for Saint-augustin, CA
# 227. Processing data for Simao, CN
# 228. Processing data for Purpe, RU
# 229. Processing data for Srednekolymsk, RU
# 230. Processing data for Edd, ER
# 231. Processing data for Halifax, CA
# 232. Processing data for Kaitangata, NZ
# 233. Processing data for Marienburg, PL
# 234. Processing data for Iqaluit, CA
# 235. Processing data for Santa isabel do rio negro, BR
# 236. Processing data for Pisco, PE
#
# 237. City - Tumannyy is not found! Skipping.....
#
# 238. Processing data for Bazarnyye mataki, RU
# 239. Processing data for Roma, US
# 240. Processing data for Pangnirtung, CA
# 241. Processing data for Pedasi, PA
#
# 242. City - Bacuit is not found! Skipping.....
#
# 243. Processing data for Gao, ML
# 244. Processing data for La palma, US
#
# 245. City - Karauzyak is not found! Skipping.....
#
# 246. Processing data for Ahuimanu, US
# 247. Processing data for Asau, RO
# 248. Processing data for Kamaishi, JP
# 249. Processing data for Iquitos, PE
#
# 250. City - Ijaki is not found! Skipping.....
#
# 251. Processing data for Krasnoselkup, RU
# 252. Processing data for Kainantu, PG
# 253. Processing data for Floro, NO
# 254. Processing data for Cap malheureux, MU
# 255. Processing data for Sahuaripa, MX
# 256. Processing data for Vestmanna, FO
# 257. Processing data for Laguna, US
# 258. Processing data for Esperance, AU
# 259. Processing data for Soe, ID
# 260. Processing data for Mount isa, AU
# 261. Processing data for Port lincoln, AU
#
# 262. City - Po is not found! Skipping.....
#
# 263. Processing data for Nevsehir, TR
# 264. Processing data for The pas, CA
# 265. Processing data for Narendranagar, IN
#
# 266. City - Rungata is not found! Skipping.....
#
# 267. Processing data for Evensk, RU
#
# 268. City - Samusu is not found! Skipping.....
#
# 269. Processing data for Ambilobe, MG
# 270. Processing data for Ilulissat, GL
# 271. Processing data for Bowen, AU
# 272. Processing data for Tiksi, RU
# 273. Processing data for Shelburne, CA
# 274. Processing data for Cherskiy, RU
# 275. Processing data for Lichinga, MZ
# 276. Processing data for Los llanos de aridane, ES
# 277. Processing data for Beringovskiy, RU
# 278. Processing data for Severo-kurilsk, RU
# 279. Processing data for Saint-georges, GD
# 280. Processing data for Saint george, US
# 281. Processing data for Matagami, CA
#
# 282. City - Tunduru is not found! Skipping.....
#
# 283. Processing data for Wilmington, US
# 284. Processing data for Manokwari, ID
# 285. Processing data for Doctor juan leon mallorquin, PY
# 286. Processing data for Brooks, CA
# 287. Processing data for Acapulco, MX
# 288. Processing data for West fargo, US
# 289. Processing data for Moa, CU
# 290. Processing data for Babu, CN
# 291. Processing data for Watsa, CD
# 292. Processing data for Airai, TL
# 293. Processing data for Turukhansk, RU
# 294. Processing data for Tolmachevo, RU
# 295. Processing data for Haimen, CN
# 296. Processing data for Iberia, US
# 297. Processing data for Petropavlovka, RU
# 298. Processing data for Kemijarvi, FI
# 299. Processing data for Sibu, MY
# 300. Processing data for Falmouth, GB
# 301. Processing data for Srivardhan, IN
# 302. Processing data for Qinhuangdao, CN
# 303. Processing data for Manggar, ID
# 304. Processing data for Waipawa, NZ
# 305. Processing data for Pilar, BR
# 306. Processing data for Kavaratti, IN
# 307. Processing data for Cidreira, BR
# 308. Processing data for Naze, JP
# 309. Processing data for Valdosta, US
# 310. Processing data for Chapais, CA
# 311. Processing data for Namatanai, PG
# 312. Processing data for Laukaa, RU
# 313. Processing data for Kuhdasht, IR
# 314. Processing data for Spencer, US
# 315. Processing data for Linhares, BR
# 316. Processing data for Midyat, TR
# 317. Processing data for Sfantu gheorghe, RO
# 318. Processing data for Chuy, UY
# 319. Processing data for Zhigansk, RU
# 320. Processing data for Koulikoro, ML
# 321. Processing data for Ust-maya, RU
# 322. Processing data for Tulle, FR
# 323. Processing data for Tuatapere, NZ
# 324. Processing data for Vilhena, BR
# 325. Processing data for Truckee, US
# 326. Processing data for Namibe, AO
# 327. Processing data for Ixtapa, MX
# 328. Processing data for Guarare, PA
# 329. Processing data for Itoman, JP
# 330. Processing data for Mackenzie, CA
#
# 331. City - Ningan is not found! Skipping.....
#
#
# 332. City - Kegayli is not found! Skipping.....
#
# 333. Processing data for Sale, MA
# 334. Processing data for Batagay-alyta, RU
# 335. Processing data for Palmeirais, BR
# 336. Processing data for Pontes e lacerda, BR
# 337. Processing data for Quatre cocos, MU
# 338. Processing data for Mutuipe, BR
# 339. Processing data for Guerrero negro, MX
# 340. Processing data for Vung tau, VN
#
# 341. City - Temaraia is not found! Skipping.....
#
# 342. Processing data for Pierre, US
# 343. Processing data for Chalmette, US
# 344. Processing data for Deputatskiy, RU
# 345. Processing data for Hofn, IS
# 346. Processing data for Kota belud, MY
# 347. Processing data for Abu dhabi, AE
# 348. Processing data for Half moon bay, US
# 349. Processing data for Dingle, PH
#
# 350. City - Marcona is not found! Skipping.....
#
# 351. Processing data for Doha, QA
# 352. Processing data for Karratha, AU
# 353. Processing data for Manono, CD
# 354. Processing data for Amapa, BR
# 355. Processing data for Mahibadhoo, MV
#
# 356. City - Warqla is not found! Skipping.....
#
# 357. Processing data for Polyarnyy, RU
# 358. Processing data for Mapiripan, CO
# 359. Processing data for Shimoda, JP
# 360. Processing data for North bend, US
#
# 361. City - Grand river south east is not found! Skipping.....
#
#
# 362. City - Teul is not found! Skipping.....
#
# 363. Processing data for Champerico, GT
# 364. Processing data for Vila velha, BR
# 365. Processing data for Port hawkesbury, CA
# 366. Processing data for Flinders, AU
# 367. Processing data for Dunedin, NZ
# 368. Processing data for Inirida, CO
# 369. Processing data for Ambulu, ID
# 370. Processing data for Kansanshi, ZM
# 371. Processing data for Tura, IN
# 372. Processing data for Tomatlan, MX
# 373. Processing data for Sao filipe, CV
# 374. Processing data for Victoria, HK
# 375. Processing data for Parana, AR
# 376. Processing data for Ilo, PE
# 377. Processing data for Soyo, AO
# 378. Processing data for Butterworth, MY
# 379. Processing data for Constitucion, CL
# 380. Processing data for Opuwo, NA
# 381. Processing data for Shatalovo, RU
# 382. Processing data for Flin flon, CA
# 383. Processing data for Grand sable, MU
# 384. Processing data for Subtanjalla, PE
# 385. Processing data for Imeni poliny osipenko, RU
# 386. Processing data for Coihaique, CL
# 387. Processing data for Gamba, GA
# 388. Processing data for Zastron, ZA
# 389. Processing data for Akyab, MM
# 390. Processing data for Marathon, US
# 391. Processing data for Benguela, AO
#
# 392. City - Cockburn harbour is not found! Skipping.....
#
# 393. Processing data for Pristen, RU
# 394. Processing data for Touba, CI
# 395. Processing data for Tynda, RU
# 396. Processing data for Dauphin, CA
# 397. Processing data for Sitka, US
# 398. Processing data for Marawi, PH
# 399. Processing data for George town, MY
# 400. Processing data for Lucapa, AO
# 401. Processing data for Chunskiy, RU
# 402. Processing data for Tocopilla, CL
# 403. Processing data for Gandai, IN
# 404. Processing data for Yenagoa, NG
# 405. Processing data for Asfi, MA
# 406. Processing data for Pueblo nuevo, MX
# 407. Processing data for Vilcun, CL
# 408. Processing data for Padang, ID
# 409. Processing data for Barra dos coqueiros, BR
#
# 410. City - Mocambique is not found! Skipping.....
#
# 411. Processing data for Rodrigues alves, BR
# 412. Processing data for Borovoy, RU
# 413. Processing data for Hobyo, SO
# 414. Processing data for Fukue, JP
# 415. Processing data for Tahara, JP
# 416. Processing data for Caraballeda, VE
# 417. Processing data for Lompoc, US
#
# 418. City - Tsihombe is not found! Skipping.....
# 419. Processing data for Sterling, US
# 420. Processing data for Tezpur, IN
# 421. Processing data for Lasa, IT
# 422. Processing data for Sokolo, ML
#
# 423. City - Bednodemyanovsk is not found! Skipping.....
#
# 424. Processing data for Tamiahua, MX
# 425. Processing data for Palestine, PS
#
# 426. City - Yeletskiy is not found! Skipping.....
#
# 427. Processing data for Samarai, PG
# 428. Processing data for Tecoanapa, MX
# 429. Processing data for Lebu, CL
# 430. Processing data for Birao, CF
# 431. Processing data for Bathsheba, BB
# 432. Processing data for Mogadishu, SO
# 433. Processing data for Whitehaven, GB
# 434. Processing data for Boa vista, BR
# 435. Processing data for Te anau, NZ
# 436. Processing data for Touros, BR
#
# 437. City - Nizhneyansk is not found! Skipping.....
#
#
# 438. City - Buariki is not found! Skipping.....
#
# 439. Processing data for Bolobo, CD
#
# 440. City - Fort saint john is not found! Skipping.....
#
# 441. Processing data for Oga, IT
# 442. Processing data for Atbasar, KZ
# 443. Processing data for Husavik, IS
# 444. Processing data for Sorland, NO
# 445. Processing data for Winnemucca, US
#
# 446. City - Labutta is not found! Skipping.....
#
# 447. Processing data for Mumford, GH
# 448. Processing data for Canico, PT
# 449. Processing data for Ishigaki, JP
# 450. Processing data for Bournemouth, GB
# 451. Processing data for Mizdah, LY
# 452. Processing data for Banjar, ID
# 453. Processing data for Vanavara, RU
# 454. Processing data for San miguel de cauri, PE
# 455. Processing data for Antofagasta, CL
#
# 456. City - Karakendzha is not found! Skipping.....
#
# 457. Processing data for Araouane, ML
# 458. Processing data for Batemans bay, AU
# 459. Processing data for Mayumba, GA
# 460. Processing data for Wylie, US
#
# 461. City - Westpunt is not found! Skipping.....
#
# 462. Processing data for Panaba, MX
# 463. Processing data for Tyukhtet, RU
# 464. Processing data for Kuala lipis, MY
# 465. Processing data for Pacific grove, US
# 466. Processing data for Kozan, TR
# 467. Processing data for Shetpe, KZ
# 468. Processing data for Madang, PG
# 469. Processing data for Goundam, ML
# 470. Processing data for Raudeberg, NO
# 471. Processing data for Ponta do sol, PT
# 472. Processing data for Sena madureira, BR
# 473. Processing data for Leua, SK
#
# 474. City - Yanan is not found! Skipping.....
#
#
# 475. City - Paradwip is not found! Skipping.....
#
# 476. Processing data for Northam, GB
# 477. Processing data for Maniitsoq, GL
# 478. Processing data for Alexandria, EG
# 479. Processing data for Sangar, RU
#
# 480. City - Lolua is not found! Skipping.....
#
# 481. Processing data for Zhoucheng, CN
# 482. Processing data for Grand-santi, GF
# 483. Processing data for Umm lajj, SA
# 484. Processing data for Putina, PE
# 485. Processing data for Ouro preto do oeste, BR
# 486. Processing data for Port moresby, PG
# 487. Processing data for Sompeta, IN
# 488. Processing data for Mayo, US
# 489. Processing data for Honiara, SB
# 490. Processing data for Nanakuli, US
# 491. Processing data for Stephenville crossing, CA
# 492. Processing data for Hami, CN
#
# 493. City - Bargal is not found! Skipping.....
#
# 494. Processing data for Kungurtug, RU
# 495. Processing data for Axim, GH
# 496. Processing data for Codajas, BR
# 497. Processing data for Ranong, TH
# 498. Processing data for Svetlyy, RU
# 499. Processing data for Karagay, RU
# 500. Processing data for Nipawin, CA
# 501. Processing data for Kungsbacka, SE
# 502. Processing data for Yar-sale, RU
# 503. Processing data for Grand gaube, MU
# 504. Processing data for Ligayan, PH
# 505. Processing data for Sirpur, IN
# 506. Processing data for Quibdo, CO
# 507. Processing data for Carlyle, US
# 508. Processing data for Cockburn town, TC
# 509. Processing data for Altamont, US
# 510. Processing data for San-pedro, CI
# 511. Processing data for Ust-tsilma, RU
# 512. Processing data for Najran, SA
#
# ^^^^^^^^^^^^^^^^^^^^^^^^
# Data Retrieval Complete
#
# ^^^^^^^^^^^^^^^^^^^^^^^^

# %% [markdown]
# ### Convert Raw Data to DataFrame
#
# * Display the DataFrame
# * Export the city data into a .csv.

# %%
# Convert the data into Pandas DataFrame
Cities_Data_df = pd.DataFrame(Cities_Data)

# Output File (CSV)
#output_data_file = "../output_data/cities.csv"

# Export the City_Data into a csv
#Cities_Data_df.to_csv(output_data_file, index_label="City_ID")

Cities_Data_df
# Out:
#               City Country  Latitude  Longitude  Max Temp  Humidity  \
# 0          Ushuaia      AR    -54.80     -68.30     44.60        81
# 1        Busselton      AU    -33.65     115.33     57.99        75
# 2          Salalah      OM     17.02      54.09     84.20        83
# 3            Muros      ES     42.78      -9.06     60.01        82
# 4      East london      ZA    -33.02      27.91     64.24        75
# ..             ...     ...       ...        ...       ...       ...
# 459  Cockburn town      TC     21.46     -71.14     80.06        76
# 460       Altamont      US     42.21    -121.74     70.00        22
# 461      San-pedro      CI      4.75      -6.64     79.79        90
# 462     Ust-tsilma      RU     65.44      52.15     36.43        96
# 463         Najran      SA     17.49      44.13     66.20        93
#
#      Cloudiness  Wind Speed
# 0             0       26.40
# 1            99       15.75
# 2            20        5.82
# 3            37       17.00
# 4             0        8.16
# ..          ...         ...
# 459          70       10.94
# 460          40        4.70
# 461          99        4.25
# 462          90        4.76
# 463          75       16.11
#
# [464 rows x 8 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
# Extract relevant fields from the data frame

Latitudes = Cities_Data_df["Latitude"]
Longitudes = Cities_Data_df["Longitude"]
Temperatures = Cities_Data_df["Max Temp"]
Humudities = Cities_Data_df["Humidity"]
Cloudiness = Cities_Data_df["Cloudiness"]
Wind_speeds = Cities_Data_df["Wind Speed"]

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
from matplotlib import style
style.use('seaborn')

# Build a scatter plot for latitude vs. temperature

plt.figure(figsize=(9, 6), facecolor = 'white')

plt.scatter(Latitudes, 
            Temperatures,
            facecolors = "blue",
            marker="o",
            edgecolor="k",
            linewidths=1,  
            alpha=0.75,
            label="Cities"
           )

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"), 
          color = "darkblue", fontsize = 17, pad = 20)

plt.xlabel("Latitude", color = "darkblue", fontsize = 15)
plt.ylabel("Max Temperature (F)", color = "darkblue", fontsize = 15)


plt.grid(True)

# Save the figure
plt.savefig("images/LatVsMaxTemp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for latitude vs. Humidity

plt.figure(figsize=(9,6), facecolor = 'white')

plt.scatter(Latitudes, 
            Humudities,
            facecolors = "b",
            marker="o",
            edgecolor="k",
            linewidths=1,  
            alpha=0.75,
            label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"), 
          color = "darkblue", 
          fontsize = 17, 
          pad = 20)

plt.xlabel("Latitude", color = "darkblue", fontsize = 15)
plt.ylabel("Humidity (%)", color = "darkblue", fontsize = 15)

plt.grid(True)

# Save the figure
plt.savefig("images/LatVsHumidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for latitude vs. Cloudiness

plt.figure(figsize=(9,6),facecolor = 'white')

plt.scatter(Latitudes, 
            Cloudiness,
            facecolors = "blue",
            marker="o",
            edgecolor="k",
            linewidths=1,  
            alpha=0.75,
            label="Cities")

# Incorporate the other graph properties

plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"), color = "darkblue", fontsize = 17, pad = 20)

plt.xlabel("Latitude", color = "darkblue", fontsize = 15)
plt.ylabel("Cloudiness (%)", color = "darkblue", fontsize = 15)

plt.grid(True)

# Save the figure
plt.savefig("images/LatVsCloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for latitude vs. Wind Speed


plt.figure(figsize=(9,6), dpi=80)

plt.scatter(Latitudes, 
            Wind_speeds,
            marker="o",
            facecolors = "b",
            edgecolor="k",
            linewidths=1,  
            alpha=0.75,
            label="Cities")

# Incorporate the other graph properties

plt.title("Latitude vs. Wind Speed (%s)" % time.strftime("%x"), color = "darkblue", fontsize = 17, pad = 20)

plt.xlabel("Latitude", color = "darkblue", fontsize = 15)
plt.ylabel("Wind Speed", color = "darkblue", fontsize = 15)

plt.grid(True)

# Save the figure

plt.savefig("images/LatVsWindSpd.png")

# Show plot

plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

def linear_reg_plot(x_values, y_values, title, x_label, y_label, line_eq_coord):

    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    regress_values = x_values * slope + intercept
    
    # Build the equation y = mx + c

    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Build a scatter plot for the relevant fields
    
    plt.figure(figsize=(9,6))
    
    plt.scatter(x_values,y_values,
                facecolors = "blue",
                marker="o",
                edgecolor="darkblue",
                linewidths=1,  
                alpha=0.75)
    
    plt.plot(x_values,regress_values,"g-")
    
    # Incorporate the other graph properties
    
    plt.title(title, color = "darkblue", fontsize = 18, pad = 20)
    
    plt.xlabel(x_label, color = "darkblue", fontsize = 15)
    plt.ylabel(y_label, color = "darkblue", fontsize = 15)
    
    # Display the line equation on the map
    
    plt.annotate(line_eq, line_eq_coord, fontsize = 18, color = "darkblue")

    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
Northern_hemi_df = Cities_Data_df.loc[Cities_Data_df['Latitude']>=0]
Northern_hemi_df
# Out:
#               City Country  Latitude  Longitude  Max Temp  Humidity  \
# 2          Salalah      OM     17.02      54.09     84.20        83
# 3            Muros      ES     42.78      -9.06     60.01        82
# 6         Katsuura      JP     35.13     140.30     73.00        93
# 8          Pahrump      US     36.21    -115.98     87.01         8
# 9        Wattegama      LK      6.80      81.48     75.72        86
# ..             ...     ...       ...        ...       ...       ...
# 459  Cockburn town      TC     21.46     -71.14     80.06        76
# 460       Altamont      US     42.21    -121.74     70.00        22
# 461      San-pedro      CI      4.75      -6.64     79.79        90
# 462     Ust-tsilma      RU     65.44      52.15     36.43        96
# 463         Najran      SA     17.49      44.13     66.20        93
#
#      Cloudiness  Wind Speed
# 2            20        5.82
# 3            37       17.00
# 6            75        3.36
# 8             0        5.01
# 9           100        2.01
# ..          ...         ...
# 459          70       10.94
# 460          40        4.70
# 461          99        4.25
# 462          90        4.76
# 463          75       16.11
#
# [313 rows x 8 columns]

# %%
Southern_hemi_df = Cities_Data_df.loc[Cities_Data_df['Latitude']<0]
Southern_hemi_df
# Out:
#                     City Country  Latitude  Longitude  Max Temp  Humidity  \
# 0                Ushuaia      AR    -54.80     -68.30     44.60        81
# 1              Busselton      AU    -33.65     115.33     57.99        75
# 4            East london      ZA    -33.02      27.91     64.24        75
# 5             Itupiranga      BR     -5.13     -49.33     80.60       100
# 7               Belmonte      BR    -15.86     -38.88     77.00        69
# ..                   ...     ...       ...        ...       ...       ...
# 437  Ouro preto do oeste      BR    -10.75     -62.22     74.91        84
# 438         Port moresby      PG     -9.44     147.18     79.59        85
# 441              Honiara      SB     -9.43     159.95     89.60        66
# 447              Codajas      BR     -3.84     -62.06     76.55        94
# 454          Grand gaube      MU    -20.01      57.66     73.00        81
#
#      Cloudiness  Wind Speed
# 0             0       26.40
# 1            99       15.75
# 4             0        8.16
# 5            20        2.24
# 7            40        4.70
# ..          ...         ...
# 437          35        1.01
# 438         100       10.85
# 441          20        3.36
# 447          97        1.63
# 454           6        3.00
#
# [151 rows x 8 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear_reg_plot(Northern_hemi_df["Latitude"],
                Northern_hemi_df["Max Temp"],
                "Northern Hemisphere: Latitude vs. Max Temp",
                "Latitude",
                "Max Temp",
                (60,60))

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linear_reg_plot(Southern_hemi_df["Latitude"],
                Southern_hemi_df["Max Temp"],
                "Southern Hemisphere: Latitude vs. Max Temp",
                "Latitude",
                "Max Temp",
                (-20,50))

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_reg_plot(Northern_hemi_df["Latitude"],
                Northern_hemi_df["Humidity"],
                "Northern Hemisphere: Latitude vs. Humidity",
                "Latitude",
                "Humidity",
                (50,20))

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linear_reg_plot(Southern_hemi_df["Latitude"],
                Southern_hemi_df["Humidity"],
                "Southern Hemisphere: Latitude vs. Humidity",
                "Latitude",
                "Humidity",
                (-12,40))

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_reg_plot(Northern_hemi_df["Latitude"],
                Northern_hemi_df["Cloudiness"],
                "Northern Hemisphere \n Latitude vs. Max Temp",
                "Latitude",
                "Cloudiness",
                (20,60))

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linear_reg_plot(Southern_hemi_df["Latitude"],
                Southern_hemi_df["Cloudiness"],
                "Southern Hemisphere: Latitude vs. Cloudiness",
                "Latitude",
                "Cloudiness",
                (-20,60))

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_reg_plot(Northern_hemi_df["Latitude"],
                Northern_hemi_df["Wind Speed"],
                "Northern Hemisphere: Latitude vs. Wind Speed",
                "Latitude",
                "Wind Speed",
                (10,25))

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linear_reg_plot(Southern_hemi_df["Latitude"],
                Southern_hemi_df["Wind Speed"],
                "Southern Hemisphere: Latitude vs. Wind Speed",
                "Latitude",
                "Wind Speed",
                (-56,15))

# %%
  
# to read csv file named "samplee" 
a = pd.read_csv("Cities.csv") 
  
# to save as html file 
# named as "Table" 
a.to_html("Table.html") 
  
# assign it to a  
# variable (string) 
html_file = a.to_html() 
html_file.split()
# Out:
# ['<table',
#  'border="1"',
#  'class="dataframe">',
#  '<thead>',
#  '<tr',
#  'style="text-align:',
#  'right;">',
#  '<th></th>',
#  '<th>City_ID</th>',
#  '<th>City</th>',
#  '<th>Country</th>',
#  '<th>Latitude</th>',
#  '<th>Longitude</th>',
#  '<th>Max',
#  'Temp</th>',
#  '<th>Humidity</th>',
#  '<th>Cloudiness</th>',
#  '<th>Wind',
#  'Speed</th>',
#  '</tr>',
#  '</thead>',
#  '<tbody>',
#  '<tr>',
#  '<th>0</th>',
#  '<td>0</td>',
#  '<td>Catamarca</td>',
#  '<td>AR</td>',
#  '<td>-28.47</td>',
#  '<td>-65.79</td>',
#  '<td>66.99</td>',
#  '<td>79</td>',
#  '<td>6</td>',
#  '<td>1.99</td>',
#  '</tr>',
#  '<tr>',
#  '<th>1</th>',
#  '<td>1</td>',
#  '<td>Hopelchen</td>',
#  '<td>MX</td>',
#  '<td>19.77</td>',
#  '<td>-89.85</td>',
#  '<td>86.00</td>',
#  '<td>74</td>',
#  '<td>20</td>',
#  '<td>11.41</td>',
#  '</tr>',
#  '<tr>',
#  '<th>2</th>',
#  '<td>2</td>',
#  '<td>Huilong</td>',
#  '<td>CN</td>',
#  '<td>31.81</td>',
#  '<td>121.66</td>',
#  '<td>64.99</td>',
#  '<td>94</td>',
#  '<td>100</td>',
#  '<td>7.00</td>',
#  '</tr>',
#  '<tr>',
#  '<th>3</th>',
#  '<td>3</td>',
#  '<td>Port',
#  'alfred</td>',
#  '<td>ZA</td>',
#  '<td>-33.59</td>',
#  '<td>26.89</td>',
#  '<td>60.01</td>',
#  '<td>88</td>',
#  '<td>0</td>',
#  '<td>1.01</td>',
#  '</tr>',
#  '<tr>',
#  '<th>4</th>',
#  '<td>4</td>',
#  '<td>Pangnirtung</td>',
#  '<td>CA</td>',
#  '<td>66.15</td>',
#  '<td>-65.71</td>',
#  '<td>12.20</td>',
#  '<td>78</td>',
#  '<td>90</td>',
#  '<td>14.99</td>',
#  '</tr>',
#  '<tr>',
#  '<th>5</th>',
#  '<td>5</td>',
#  '<td>Katangli</td>',
#  '<td>RU</td>',
#  '<td>51.71</td>',
#  '<td>143.23</td>',
#  '<td>31.75</td>',
#  '<td>94</td>',
#  '<td>100</td>',
#  '<td>16.64</td>',
#  '</tr>',
#  '<tr>',
#  '<th>6</th>',
#  '<td>6</td>',
#  '<td>Cocal</td>',
#  '<td>BR</td>',
#  '<td>-28.62</td>',
#  '<td>-49.35</td>',
#  '<td>61.16</td>',
#  '<td>64</td>',
#  '<td>0</td>',
#  '<td>3.76</td>',
#  '</tr>',
#  '<tr>',
#  '<th>7</th>',
#  '<td>7</td>',
#  '<td>Alyangula</td>',
#  '<td>AU</td>',
#  '<td>-13.85</td>',
#  '<td>136.42</td>',
#  '<td>80.60</td>',
#  '<td>54</td>',
#  '<td>87</td>',
#  '<td>5.82</td>',
#  '</tr>',
#  '<tr>',
#  '<th>8</th>',
#  '<td>8</td>',
#  '<td>Katsina</td>',
#  '<td>NG</td>',
#  '<td>12.99</td>',
#  '<td>7.60</td>',
#  '<td>85.60</td>',
#  '<td>32</td>',
#  '<td>58</td>',
#  '<td>12.68</td>',
#  '</tr>',
#  '<tr>',
#  '<th>9</th>',
#  '<td>9</td>',
#  '<td>Saint-philippe</td>',
#  '<td>RE</td>',
#  '<td>-21.36</td>',
#  '<td>55.77</td>',
#  '<td>75.20</td>',
#  '<td>73</td>',
#  '<td>43</td>',
#  '<td>5.82</td>',
#  '</tr>',
#  '<tr>',
#  '<th>10</th>',
#  '<td>10</td>',
#  '<td>Sarangani</td>',
#  '<td>PH</td>',
#  '<td>5.40</td>',
#  '<td>125.46</td>',
#  '<td>83.95</td>',
#  '<td>71</td>',
#  '<td>0</td>',
#  '<td>2.75</td>',
#  '</tr>',
#  '<tr>',
#  '<th>11</th>',
#  '<td>11</td>',
#  '<td>Punta',
#  'arenas</td>',
#  '<td>CL</td>',
#  '<td>-53.15</td>',
#  '<td>-70.92</td>',
#  '<td>37.40</td>',
#  '<td>86</td>',
#  '<td>0</td>',
#  '<td>8.05</td>',
#  '</tr>',
#  '<tr>',
#  '<th>12</th>',
#  '<td>12</td>',
#  '<td>Vaini</td>',
#  '<td>TO</td>',
#  '<td>-21.20</td>',
#  '<td>-175.20</td>',
#  '<td>82.40</td>',
#  '<td>74</td>',
#  '<td>40</td>',
#  '<td>5.82</td>',
#  '</tr>',
#  '<tr>',
#  '<th>13</th>',
#  '<td>13</td>',
#  '<td>Bredasdorp</td>',
#  '<td>ZA</td>',
#  '<td>-34.53</td>',
#  '<td>20.04</td>',
#  '<td>51.80</td>',
#  '<td>87</td>',
#  '<td>23</td>',
#  '<td>4.70</td>',
#  '</tr>',
#  '<tr>',
#  '<th>14</th>',
#  '<td>14</td>',
#  '<td>Teguldet</td>',
#  '<td>RU</td>',
#  '<td>57.31</td>',
#  '<td>88.17</td>',
#  '<td>37.65</td>',
#  '<td>87</td>',
#  '<td>100</td>',
#  '<td>13.33</td>',
#  '</tr>',
#  '<tr>',
#  '<th>15</th>',
#  '<td>15</td>',
#  '<td>Nome</td>',
#  '<td>US</td>',
#  '<td>64.50</td>',
#  '<td>-165.41</td>',
#  '<td>44.60</td>',
#  '<td>45</td>',
#  '<td>1</td>',
#  '<td>6.93</td>',
#  '</tr>',
#  '<tr>',
#  '<th>16</th>',
#  '<td>16</td>',
#  '<td>Noyabrsk</td>',
#  '<td>RU</td>',
#  '<td>63.20</td>',
#  '<td>75.45</td>',
#  '<td>23.45</td>',
#  '<td>89</td>',
#  '<td>0</td>',
#  '<td>9.40</td>',
#  '</tr>',
#  '<tr>',
#  '<th>17</th>',
#  '<td>17</td>',
#  '<td>Mataura</td>',
#  '<td>NZ</td>',
#  '<td>-46.19</td>',
#  '<td>168.86</td>',
#  '<td>43.56</td>',
#  '<td>87</td>',
#  '<td>82</td>',
#  '<td>9.15</td>',
#  '</tr>',
#  '<tr>',
#  '<th>18</th>',
#  '<td>18</td>',
#  '<td>Avarua</td>',
#  '<td>CK</td>',
#  '<td>-21.21</td>',
#  '<td>-159.78</td>',
#  '<td>80.60</td>',
#  '<td>83</td>',
#  '<td>7</td>',
#  '<td>5.82</td>',
#  '</tr>',
#  '<tr>',
#  '<th>19</th>',
#  '<td>19</td>',
#  '<td>Ushuaia</td>',
#  '<td>AR</td>',
#  '<td>-54.80</td>',
#  '<td>-68.30</td>',
#  '<td>44.60</td>',
#  '<td>81</td>',
#  '<td>0</td>',
#  '<td>26.40</td>',
#  '</tr>',
#  '<tr>',
#  '<th>20</th>',
#  '<td>20</td>',
#  '<td>Yar-sale</td>',
#  '<td>RU</td>',
#  '<td>66.83</td>',
#  '<td>70.83</td>',
#  '<td>14.56</td>',
#  '<td>91</td>',
#  '<td>67</td>',
#  '<td>8.32</td>',
#  '</tr>',
#  '<tr>',
#  '<th>21</th>',
#  '<td>21</td>',
#  '<td>Constitucion</td>',
#  '<td>CL</td>',
#  '<td>-35.33</td>',
#  '<td>-72.42</td>',
#  '<td>57.43</td>',
#  '<td>82</td>',
#  '<td>92</td>',
#  '<td>7.31</td>',
#  '</tr>',
#  '<tr>',
#  '<th>22</th>',
#  '<td>22</td>',
#  '<td>New',
#  'norfolk</td>',
#  '<td>AU</td>',
#  '<td>-42.78</td>',
#  '<td>147.06</td>',
#  '<td>50.00</td>',
#  '<td>85</td>',
#  '<td>61</td>',
#  '<td>3.22</td>',
#  '</tr>',
#  '<tr>',
#  '<th>23</th>',
#  '<td>23</td>',
#  '<td>Kristiansund</td>',
#  '<td>NO</td>',
#  '<td>63.11</td>',
#  '<td>7.73</td>',
#  '<td>37.40</td>',
#  '<td>69</td>',
#  '<td>93</td>',
#  '<td>10.29</td>',
#  '</tr>',
#  '<tr>',
#  '<th>24</th>',
#  '<td>24</td>',
#  '<td>Aleksandrov',
#  'gay</td>',
#  '<td>RU</td>',
#  '<td>50.15</td>',
#  '<td>48.57</td>',
#  '<td>60.71</td>',
#  '<td>52</td>',
#  '<td>21</td>',
#  '<td>12.37</td>',
#  '</tr>',
#  '<tr>',
#  '<th>25</th>',
#  '<td>25</td>',
#  '<td>Barrow</td>',
#  '<td>US</td>',
#  '<td>71.29</td>',
#  '<td>-156.79</td>',
#  '<td>10.40</td>',
#  '<td>85</td>',
#  '<td>1</td>',
#  '<td>12.75</td>',
#  '</tr>',
#  '<tr>',
#  '<th>26</th>',
#  '<td>26</td>',
#  '<td>Rikitea</td>',
#  '<td>PF</td>',
#  '<td>-23.12</td>',
#  '<td>-134.97</td>',
#  '<td>73.42</td>',
#  '<td>72</td>',
#  '<td>98</td>',
#  '<td>14.47</td>',
#  '</tr>',
#  '<tr>',
#  '<th>27</th>',
#  '<td>27</td>',
#  '<td>Ponta',
#  'do',
#  'sol</td>',
#  '<td>PT</td>',
#  '<td>32.67</td>',
#  '<td>-17.10</td>',
#  '<td>66.20</td>',
#  '<td>59</td>',
#  '<td>20</td>',
#  '<td>6.93</td>',
#  '</tr>',
#  '<tr>',
#  '<th>28</th>',
#  '<td>28</td>',
#  '<td>Saldanha</td>',
#  '<td>ZA</td>',
#  '<td>-33.01</td>',
#  '<td>17.94</td>',
#  '<td>53.60</td>',
#  '<td>87</td>',
#  '<td>57</td>',
#  '<td>3.36</td>',
#  '</tr>',
#  '<tr>',
#  '<th>29</th>',
#  '<td>29</td>',
#  '<td>Sinnamary</td>',
#  '<td>GF</td>',
#  '<td>5.38</td>',
#  '<td>-52.95</td>',
#  '<td>78.87</td>',
#  '<td>86</td>',
#  '<td>93</td>',
#  '<td>13.00</td>',
#  '</tr>',
#  '<tr>',
#  '<th>30</th>',
#  '<td>30</td>',
#  '<td>Kupang</td>',
#  '<td>ID</td>',
#  '<td>-10.17</td>',
#  '<td>123.58</td>',
#  '<td>80.60</td>',
#  '<td>78</td>',
#  '<td>20</td>',
#  '<td>12.75</td>',
#  '</tr>',
#  '<tr>',
#  '<th>31</th>',
#  '<td>31</td>',
#  '<td>Codrington</td>',
#  '<td>AU</td>',
#  '<td>-38.27</td>',
#  '<td>141.97</td>',
#  '<td>55.96</td>',
#  '<td>72</td>',
#  '<td>1</td>',
#  '<td>10.74</td>',
#  '</tr>',
#  '<tr>',
#  '<th>32</th>',
#  '<td>32</td>',
#  '<td>Acari</td>',
#  '<td>PE</td>',
#  '<td>-15.43</td>',
#  '<td>-74.62</td>',
#  '<td>72.72</td>',
#  '<td>57</td>',
#  '<td>82</td>',
#  '<td>3.42</td>',
#  '</tr>',
#  '<tr>',
#  '<th>33</th>',
#  '<td>33</td>',
#  '<td>Iquique</td>',
#  '<td>CL</td>',
#  '<td>-20.22</td>',
#  '<td>-70.14</td>',
#  '<td>66.20</td>',
#  '<td>68</td>',
#  '<td>70</td>',
#  '<td>13.87</td>',
#  '</tr>',
#  '<tr>',
#  '<th>34</th>',
#  '<td>34</td>',
#  '<td>Sitka</td>',
#  '<td>US</td>',
#  '<td>57.05</td>',
#  '<td>-135.33</td>',
#  '<td>55.40</td>',
#  '<td>43</td>',
#  '<td>40</td>',
#  '<td>10.29</td>',
#  '</tr>',
#  '<tr>',
#  '<th>35</th>',
#  '<td>35</td>',
#  '<td>Lavrentiya</td>',
#  '<td>RU</td>',
#  '<td>65.58</td>',
#  '<td>-171.00</td>',
#  '<td>32.23</td>',
#  '<td>92</td>',
#  '<td>0</td>',
#  '<td>4.94</td>',
#  '</tr>',
#  '<tr>',
#  '<th>36</th>',
#  '<td>36</td>',
#  '<td>Caceres</td>',
#  '<td>ES</td>',
#  '<td>39.52</td>',
#  '<td>-6.37</td>',
#  '<td>57.00</td>',
#  '<td>81</td>',
#  '<td>100</td>',
#  '<td>1.01</td>',
#  '</tr>',
#  '<tr>',
#  '<th>37</th>',
#  '<td>37</td>',
#  '<td>Port',
#  'lincoln</td>',
#  '<td>AU</td>',
#  '<td>-34.73</td>',
#  '<td>135.87</td>',
#  '<td>61.07</td>',
#  '<td>45</td>',
#  '<td>42</td>',
#  '<td>15.88</td>',
#  '</tr>',
#  '<tr>',
#  '<th>38</th>',
#  '<td>38</td>',
#  '<td>Payakumbuh</td>',
#  '<td>ID</td>',
#  '<td>-0.22</td>',
#  '<td>100.63</td>',
#  '<td>71.96</td>',
#  '<td>73</td>',
#  '<td>100</td>',
#  '<td>1.77</td>',
#  '</tr>',
#  '<tr>',
#  '<th>39</th>',
#  '<td>39</td>',
#  '<td>Chokurdakh</td>',
#  '<td>RU</td>',
#  '<td>70.63</td>',
#  '<td>147.92</td>',
#  '<td>21.47</td>',
#  '<td>97</td>',
#  '<td>99</td>',
#  '<td>3.56</td>',
#  '</tr>',
#  '<tr>',
#  '<th>40</th>',
#  '<td>40</td>',
#  '<td>Berbera</td>',
#  '<td>SO</td>',
#  '<td>10.44</td>',
#  '<td>45.01</td>',
#  '<td>85.78</td>',
#  '<td>75</td>',
#  '<td>62</td>',
#  '<td>8.21</td>',
#  '</tr>',
#  '<tr>',
#  '<th>41</th>',
#  '<td>41</td>',
#  '<td>Qaanaaq</td>',
#  '<td>GL</td>',
#  '<td>77.48</td>',
#  '<td>-69.36</td>',
#  '<td>16.54</td>',
#  '<td>93</td>',
#  '<td>100</td>',
#  '<td>2.71</td>',
#  '</tr>',
#  '<tr>',
#  '<th>42</th>',
#  '<td>42</td>',
#  '<td>Necochea</td>',
#  '<td>AR</td>',
#  '<td>-38.55</td>',
#  '<td>-58.74</td>',
#  '<td>57.00</td>',
#  '<td>83</td>',
#  '<td>53</td>',
#  '<td>1.99</td>',
#  '</tr>',
#  '<tr>',
#  '<th>43</th>',
#  '<td>43</td>',
#  '<td>Yellowknife</td>',
#  '<td>CA</td>',
#  '<td>62.46</td>',
#  '<td>-114.35</td>',
#  '<td>39.20</td>',
#  '<td>51</td>',
#  '<td>20</td>',
#  '<td>9.17</td>',
#  '</tr>',
#  '<tr>',
#  '<th>44</th>',
#  '<td>44</td>',
#  '<td>Jamestown</td>',
#  '<td>US</td>',
#  '<td>42.10</td>',
#  '<td>-79.24</td>',
#  '<td>46.00</td>',
#  '<td>66</td>',
#  '<td>75</td>',
#  '<td>10.29</td>',
#  '</tr>',
#  '<tr>',
#  '<th>45</th>',
#  '<td>45</td>',
#  '<td>Bambous',
#  'virieux</td>',
#  '<td>MU</td>',
#  '<td>-20.34</td>',
#  '<td>57.76</td>',
#  '<td>73.99</td>',
#  '<td>83</td>',
#  '<td>20</td>',
#  '<td>4.70</td>',
#  '</tr>',
#  '<tr>',
#  '<th>46</th>',
#  '<td>46</td>',
#  '<td>Djambala</td>',
#  '<td>CG</td>',
#  '<td>-2.54</td>',
#  '<td>14.75</td>',
#  '<td>71.82</td>',
#  '<td>69</td>',
#  '<td>79</td>',
#  '<td>3.15</td>',
#  '</tr>',
#  '<tr>',
#  '<th>47</th>',
#  '<td>47</td>',
#  '<td>Hobart</td>',
#  '<td>AU</td>',
#  '<td>-42.88</td>',
#  '<td>147.33</td>',
#  '<td>54.00</td>',
#  '<td>81</td>',
#  '<td>40</td>',
#  '<td>8.05</td>',
#  '</tr>',
#  '<tr>',
#  '<th>48</th>',
#  '<td>48</td>',
#  '<td>Busselton</td>',
#  '<td>AU</td>',
#  '<td>-33.65</td>',
#  '<td>115.33</td>',
#  '<td>57.99</td>',
#  '<td>74</td>',
#  '<td>99</td>',
#  '<td>15.75</td>',
#  '</tr>',
#  '<tr>',
#  '<th>49</th>',
#  '<td>49</td>',
#  '<td>Houston</td>',
#  '<td>US</td>',
#  '<td>29.76</td>',
#  '<td>-95.36</td>',
#  '<td>87.01</td>',
#  '<td>51</td>',
#  '<td>40</td>',
#  '<td>13.87</td>',
#  '</tr>',
#  '<tr>',
#  '<th>50</th>',
#  '<td>50</td>',
#  '<td>Butaritari</td>',
#  '<td>KI</td>',
#  '<td>3.07</td>',
#  '<td>172.79</td>',
#  '<td>82.87</td>',
#  '<td>81</td>',
#  '<td>94</td>',
#  '<td>15.57</td>',
#  '</tr>',
#  '<tr>',
#  '<th>51</th>',
#  '<td>51</td>',
#  '<td>Bluff</td>',
#  '<td>NZ</td>',
#  '<td>-46.60</td>',
#  '<td>168.33</td>',
#  '<td>45.95</td>',
#  '<td>71</td>',
#  '<td>77</td>',
#  '<td>20.78</td>',
#  '</tr>',
#  '<tr>',
#  '<th>52</th>',
#  '<td>52</td>',
#  '<td>Mahebourg</td>',
#  '<td>MU</td>',
#  '<td>-20.41</td>',
#  '<td>57.70</td>',
#  '<td>73.40</td>',
#  '<td>83</td>',
#  '<td>20</td>',
#  '<td>4.70</td>',
#  '</tr>',
#  '<tr>',
#  '<th>53</th>',
#  '<td>53</td>',
#  '<td>Clyde',
#  'river</td>',
#  '<td>CA</td>',
#  '<td>70.47</td>',
#  '<td>-68.59</td>',
#  '<td>8.60</td>',
#  '<td>84</td>',
#  '<td>1</td>',
#  '<td>6.93</td>',
#  '</tr>',
#  '<tr>',
#  '<th>54</th>',
#  '<td>54</td>',
#  '<td>Vestmannaeyjar</td>',
#  '<td>IS</td>',
#  '<td>63.44</td>',
#  '<td>-20.27</td>',
#  '<td>45.88</td>',
#  '<td>82</td>',
#  '<td>34</td>',
#  '<td>24.49</td>',
#  '</tr>',
#  '<tr>',
#  '<th>55</th>',
#  '<td>55</td>',
#  '<td>Ballybofey</td>',
#  '<td>IE</td>',
#  '<td>54.80</td>',
#  '<td>-7.78</td>',
#  '<td>42.66</td>',
#  '<td>92</td>',
#  '<td>0</td>',
#  '<td>5.14</td>',
#  '</tr>',
#  '<tr>',
#  '<th>56</th>',
#  '<td>56</td>',
#  '<td>Marzuq</td>',
#  '<td>YE</td>',
#  '<td>14.40</td>',
#  '<td>46.47</td>',
#  '<td>76.06</td>',
#  '<td>42</td>',
#  '<td>100</td>',
#  '<td>7.87</td>',
#  '</tr>',
#  '<tr>',
#  '<th>57</th>',
#  '<td>57</td>',
#  '<td>Castro</td>',
#  '<td>BR</td>',
#  '<td>-24.79</td>',
#  '<td>-50.01</td>',
#  '<td>53.31</td>',
#  '<td>54</td>',
#  '<td>0</td>',
#  '<td>2.59</td>',
#  '</tr>',
#  '<tr>',
#  '<th>58</th>',
#  '<td>58</td>',
#  '<td>Port',
#  'hedland</td>',
#  '<td>AU</td>',
#  '<td>-20.32</td>',
#  '<td>118.57</td>',
#  '<td>64.40</td>',
#  '<td>59</td>',
#  '<td>0</td>',
#  '<td>6.93</td>',
#  '</tr>',
#  '<tr>',
#  '<th>59</th>',
#  '<td>59</td>',
#  '<td>Norman',
#  'wells</td>',
#  '<td>CA</td>',
#  '<td>65.28</td>',
#  '<td>-126.83</td>',
#  '<td>39.20</td>',
#  '<td>60</td>',
#  '<td>40</td>',
#  '<td>16.11</td>',
#  '</tr>',
#  '<tr>',
#  '<th>60</th>',
#  '<td>60</td>',
#  '<td>Gazojak</td>',
#  '<td>TM</td>',
#  '<td>41.19</td>',
#  '<td>61.40</td>',
#  '<td>63.25</td>',
#  '<td>58</td>',
#  '<td>27</td>',
#  '<td>3.60</td>',
#  '</tr>',
#  '<tr>',
#  '<th>61</th>',
#  '<td>61</td>',
#  '<td>Hofn</td>',
#  '<td>IS</td>',
#  '<td>64.25</td>',
#  '<td>-15.21</td>',
#  '<td>45.09</td>',
#  '<td>80</td>',
#  '<td>100</td>',
#  '<td>19.71</td>',
#  '</tr>',
#  '<tr>',
#  '<th>62</th>',
#  '<td>62</td>',
#  '<td>Albany</td>',
#  '<td>US</td>',
#  '<td>42.60</td>',
#  '<td>-73.97</td>',
#  '<td>50.00</td>',
#  '<td>54</td>',
#  '<td>66</td>',
#  '<td>1.99</td>',
#  '</tr>',
#  '<tr>',
#  '<th>63</th>',
#  '<td>63</td>',
#  '<td>Wawa</td>',
#  '<td>NG</td>',
#  '<td>9.90</td>',
#  '<td>4.42</td>',
#  '<td>81.52</td>',
#  '<td>62</td>',
#  '<td>11</td>',
#  '<td>11.01</td>',
#  '</tr>',
#  '<tr>',
#  '<th>64</th>',
#  '<td>64</td>',
#  '<td>Ilulissat</td>',
#  '<td>GL</td>',
#  '<td>69.22</td>',
#  '<td>-51.10</td>',
#  '<td>21.20</td>',
#  '<td>62</td>',
#  '<td>100</td>',
#  '<td>11.41</td>',
#  '</tr>',
#  '<tr>',
#  '<th>65</th>',
#  '<td>65</td>',
#  '<td>Carnarvon</td>',
#  '<td>AU</td>',
#  '<td>-24.87</td>',
#  '<td>113.63</td>',
#  '<td>62.60</td>',
#  '<td>100</td>',
#  '<td>90</td>',
#  '<td>4.70</td>',
#  '</tr>',
#  '<tr>',
#  '<th>66</th>',
#  '<td>66</td>',
#  '<td>Tuktoyaktuk</td>',
#  '<td>CA</td>',
#  '<td>69.45</td>',
#  '<td>-133.04</td>',
#  '<td>17.60</td>',
#  '<td>78</td>',
#  '<td>20</td>',
#  '<td>13.87</td>',
#  '</tr>',
#  '<tr>',
#  '<th>67</th>',
#  '<td>67</td>',
#  '<td>Hami</td>',
#  '<td>CN</td>',
#  '<td>42.80</td>',
#  '<td>93.45</td>',
#  '<td>68.85</td>',
#  '<td>23</td>',
#  '<td>98</td>',
#  '<td>7.14</td>',
#  '</tr>',
#  '<tr>',
#  '<th>68</th>',
#  '<td>68</td>',
#  '<td>Tiksi</td>',
#  '<td>RU</td>',
#  '<td>71.69</td>',
#  '<td>128.87</td>',
#  '<td>19.33</td>',
#  '<td>97</td>',
#  '<td>100</td>',
#  '<td>9.57</td>',
#  '</tr>',
#  '<tr>',
#  '<th>69</th>',
#  '<td>69</td>',
#  '<td>Babu</td>',
#  '<td>CN</td>',
#  '<td>24.42</td>',
#  '<td>111.52</td>',
#  '<td>81.75</td>',
#  '<td>75</td>',
#  '<td>17</td>',
#  '<td>4.27</td>',
#  '</tr>',
#  '<tr>',
#  '<th>70</th>',
#  '<td>70</td>',
#  '<td>Atuona</td>',
#  '<td>PF</td>',
#  '<td>-9.80</td>',
#  '<td>-139.03</td>',
#  '<td>81.91</td>',
#  '<td>69</td>',
#  '<td>0</td>',
#  '<td>17.07</td>',
#  '</tr>',
#  '<tr>',
#  '<th>71</th>',
#  '<td>71</td>',
#  '<td>Severo-kurilsk</td>',
#  '<td>RU</td>',
#  '<td>50.68</td>',
#  '<td>156.12</td>',
#  '<td>38.93</td>',
#  '<td>93</td>',
#  '<td>100</td>',
#  '<td>22.10</td>',
#  '</tr>',
#  '<tr>',
#  '<th>72</th>',
#  '<td>72</td>',
#  '<td>Tumaco</td>',
#  '<td>CO</td>',
#  '<td>1.80</td>',
#  '<td>-78.82</td>',
#  '<td>79.41</td>',
#  '<td>86</td>',
#  '<td>68</td>',
#  '<td>9.62</td>',
#  '</tr>',
#  '<tr>',
#  '<th>73</th>',
#  '<td>73</td>',
#  '<td>Albania</td>',
#  '<td>AL</td>',
#  '<td>41.00</td>',
#  '<td>20.00</td>',
#  '<td>50.00</td>',
#  '<td>87</td>',
#  '<td>0</td>',
#  '<td>3.36</td>',
#  '</tr>',
#  '<tr>',
#  '<th>74</th>',
#  '<td>74</td>',
#  '<td>Cherskiy</td>',
#  '<td>RU</td>',
#  '<td>68.75</td>',
#  '<td>161.30</td>',
#  '<td>28.98</td>',
#  '<td>96</td>',
#  '<td>100</td>',
#  '<td>3.42</td>',
#  '</tr>',
#  '<tr>',
#  '<th>75</th>',
#  '<td>75</td>',
#  '<td>Gigmoto</td>',
#  '<td>PH</td>',
#  '<td>13.78</td>',
#  '<td>124.39</td>',
#  '<td>84.65</td>',
#  '<td>77</td>',
#  '<td>54</td>',
#  '<td>10.02</td>',
#  '</tr>',
#  '<tr>',
#  '<th>76</th>',
#  '<td>76</td>',
#  '<td>Vila',
#  'franca',
#  'do',
#  'campo</td>',
#  '<td>PT</td>',
#  '<td>37.72</td>',
#  '<td>-25.43</td>',
#  '<td>60.80</td>',
#  '<td>82</td>',
#  '<td>40</td>',
#  '<td>23.04</td>',
#  '</tr>',
#  '<tr>',
#  '<th>77</th>',
#  '<td>77</td>',
#  '<td>Urumqi</td>',
#  '<td>CN</td>',
#  '<td>43.80</td>',
#  '<td>87.60</td>',
#  '<td>59.00</td>',
#  '<td>62</td>',
#  '<td>77</td>',
#  '<td>2.24</td>',
#  '</tr>',
#  '<tr>',
#  '<th>78</th>',
#  '<td>78</td>',
#  '<td>Alice',
#  'springs</td>',
#  '<td>AU</td>',
#  '<td>-23.70</td>',
#  '<td>133.88</td>',
#  '<td>50.00</td>',
#  '<td>43</td>',
#  '<td>0</td>',
#  '<td>3.36</td>',
#  '</tr>',
#  '<tr>',
#  '<th>79</th>',
#  '<td>79</td>',
#  '<td>Bhatkal</td>',
#  '<td>IN</td>',
#  '<td>13.97</td>',
#  '<td>74.57</td>',
#  '<td>80.29</td>',
#  '<td>84</td>',
#  '<td>44</td>',
#  '<td>7.23</td>',
#  '</tr>',
#  '<tr>',
#  '<th>80</th>',
#  '<td>80</td>',
#  ...]
